# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from datetime import datetime 
from IPython.display import display, HTML, clear_output

# %%
# Just to have each print in the same row
def how_to_print(how):
    CSS = '''
    .output {
        '''+'flex-direction: {};'.format(how)+'''
    }
    '''

    HTML('<style>{}</style>'.format(CSS))

pd.set_option('display.max_rows', 150)
    
how_to_print('row')

# %%
r'''
dataset2018: *trusted_data* with actual ocupacion included.
    path: r'C:\Users\ing_l\Tesis grado\Data\dataset2018.csv'
    
dataset_webscraping: (DataFrame) data with the corresponding operacion (Entrada/Salida).
    path: C:\Users\ing_l\Tesis grado\Data\SUMO_data_w_operacion.csv

dataset2019: all sumo data with ocupation (requested in sumo office)
'''

dataset2018_path = r'C:\Users\ing_l\Tesis grado\Data\dataset_2018.csv'
dataset_webscraping_path = r'C:\Users\ing_l\Tesis grado\Data\dataset_webscraping.csv'
dataset2019_path = r'C:\Users\ing_l\Tesis grado\Data\dataset_2019.csv'

# %%
dataset2018 = pd.read_csv(dataset2018_path)[['id_cuadra', 'direccion', 'fecha', 'tiempo', 'operacion', 'ocupacion', 'latitud', 'longitud']]
dataset2018 = dataset2018.loc[dataset2018.id_cuadra != 1]
dataset2018['dia de la semana'] = -1
dataset2018.columns.names = ['dataset2018']

dataset_ws = pd.read_csv(dataset_webscraping_path)[['id_cuadra', 'direccion', 'fecha', 'tiempo', 'operacion', 'ocupacion', 'latitud', 'longitud']]
dataset_ws['dia de la semana'] = -1
dataset_ws.columns.names = ['dataset_ws']

dataset2019 = pd.read_csv(dataset2019_path)[['id_cuadra', 'direccion', 'fecha', 'tiempo', 'operacion', 'ocupacion', 'latitud', 'longitud']]
dataset2019['dia de la semana'] = -1
dataset2019.columns.names = ['dataset2019']

# %%
def correct_type(row):
    '''
    Corrects the dtype of fecha, tiempo and ocupación on the df
    '''
    row['fecha'] = pd.to_datetime(row['fecha'], dayfirst=True).date()
    row['tiempo'] = pd.to_datetime(row['tiempo']).time()
    row['ocupacion'] = int(row['ocupacion'])
    row['dia de la semana'] = row['fecha'].weekday()
    return row

print('Working on dataset2018...')
dataset2018 = dataset2018.apply(correct_type, axis=1).sort_values(by=['fecha', 'tiempo'])
clear_output()
print('Working on dataset_ws...')
dataset_ws = dataset_ws.apply(correct_type, axis=1).sort_values(by=['fecha', 'tiempo'])
clear_output()
print('Working on dataset2019...')
dataset2019 = dataset2019.apply(correct_type, axis=1).sort_values(by=['fecha', 'tiempo'])
clear_output()

# %%
def modify_operation(op):
    if op in 'Entrada':
        return 1
    elif op in 'Salida':
        return 0
    return -1

dataset2018['operacion'] = dataset2018['operacion'].apply(modify_operation)
dataset_ws['operacion'] = dataset_ws['operacion'].apply(modify_operation)

# %%
#Fix dataset2019 latitud and longitud
lat_long = dataset_ws[['direccion', 'latitud', 'longitud']].copy().drop_duplicates()
lat_long['direccion'] = lat_long['direccion'].apply(lambda x: x[0:-2])

for i in lat_long['direccion']:
    dataset2019.loc[dataset2019.direccion.str.contains(i), ['latitud','longitud']] = lat_long.loc[lat_long.direccion == i, ['latitud','longitud']].iloc[0].values

# %%
dataset2018
# Out:
# dataset2018  id_cuadra          direccion       fecha    tiempo  operacion  \
# 0                   82    General Paz 647  2018-01-01  07:11:00          1
# 1                   82    General Paz 647  2018-01-01  07:11:00          0
# 2                   40          Mitre 348  2018-01-01  11:26:00          1
# 3                   40          Mitre 348  2018-01-01  11:28:00          0
# 4                   61      Chacabuco 357  2018-01-01  13:09:00          1
# ...                ...                ...         ...       ...        ...
# 704746              62     9 de Julio 753  2018-06-14  10:34:00          0
# 704747              10      Rodriguez 654  2018-06-14  10:34:00          0
# 704748               9     San Martín 560  2018-06-14  10:34:00          0
# 704749              15  General Pinto 631  2018-06-14  10:34:00          0
# 704750              74          Maipu 653  2018-06-14  10:34:00          0
#
# dataset2018  ocupacion    latitud   longitud  dia de la semana
# 0                    1 -37.324173 -59.132848                 0
# 1                    0 -37.324173 -59.132848                 0
# 2                    1 -37.325260 -59.141475                 0
# 3                    0 -37.325260 -59.141475                 0
# 4                    1 -37.330374 -59.137451                 0
# ...                ...        ...        ...               ...
# 704746               0 -37.324030 -59.136498                 3
# 704747               0 -37.325723 -59.137192                 3
# 704748               0 -37.326575 -59.137315                 3
# 704749               0 -37.327418 -59.135649                 3
# 704750               0 -37.329878 -59.133842                 3
#
# [704747 rows x 9 columns]

# %%
dataset_ws
# Out:
# dataset_ws  id_cuadra          direccion       fecha    tiempo  operacion  \
# 121398             37          Mitre 846  2019-09-11  16:53:28          0
# 160259             49           Alem 852  2019-09-11  17:00:32          1
# 130247             40          Mitre 348  2019-09-11  17:10:22          0
# 218768             67    14 de Julio 347  2019-09-11  17:10:26          0
# 168633             53      Chacabuco 752  2019-09-11  17:10:28          1
# ...               ...                ...         ...       ...        ...
# 4311                2  General Pinto 545  2019-12-17  14:18:39          0
# 179682             56       Yrigoyen 557  2019-12-17  14:18:42          1
# 98270              30     San Martín 944  2019-12-17  14:18:46          0
# 140133             43          Mitre 648  2019-12-17  14:18:48          1
# 74445              21       Belgrano 540  2019-12-17  14:18:49          1
#
# dataset_ws  ocupacion    latitud   longitud  dia de la semana
# 121398              4 -37.322679 -59.134674                 2
# 160259              4 -37.322289 -59.135735                 2
# 130247              1 -37.325260 -59.141475                 2
# 218768              1 -37.331060 -59.138882                 2
# 168633              7 -37.325521 -59.140396                 2
# ...               ...        ...        ...               ...
# 4311                5 -37.327857 -59.136795                 1
# 179682              9 -37.327387 -59.137809                 1
# 98270               5 -37.324446 -59.131737                 1
# 140133              6 -37.323759 -59.137520                 1
# 74445               5 -37.329213 -59.136056                 1
#
# [281126 rows x 9 columns]

# %%
dataset2019
# Out:
# dataset2019  id_cuadra          direccion       fecha    tiempo  operacion  \
# 0                   16       Belgrano 660  2019-01-01  10:55:00          0
# 7                    1  General Pinto 545  2019-01-01  15:12:00          1
# 9                   65      Rodriguez 348  2019-01-01  15:13:00          1
# 8                    1  General Pinto 545  2019-01-01  15:15:00          0
# 10                  65      Rodriguez 348  2019-01-01  16:22:00          0
# ...                ...                ...         ...       ...        ...
# 2957257             18      Sarmiento 543  2019-12-31  19:45:00          1
# 2957258             18      Sarmiento 543  2019-12-31  19:46:00          0
# 2956381             24       Belgrano 364  2019-12-31  19:53:00          1
# 2956511             60      Chacabuco 357  2019-12-31  20:08:00          0
# 2956907             42          Mitre 948  2019-12-31  21:55:00          0
#
# dataset2019  ocupacion    latitud   longitud  dia de la semana
# 0                    0 -37.328618 -59.134464                 1
# 7                    1 -37.327857 -59.136795                 1
# 9                    1 -37.329556 -59.134932                 1
# 8                    0 -37.327857 -59.136795                 1
# 10                   0 -37.329556 -59.134932                 1
# ...                ...        ...        ...               ...
# 2957257              4 -37.325463 -59.138244                 1
# 2957258              3 -37.325463 -59.138244                 1
# 2956381              1 -37.330051 -59.138285                 1
# 2956511              0 -37.330374 -59.137451                 1
# 2956907              0 -37.322061 -59.133046                 1
#
# [2957542 rows x 9 columns]

# %% [markdown]
# ## Cuantas calles tiene cada datasets

# %%
print('dataset 2018:')
print('    id_cuadra maximo:', dataset2018.id_cuadra.max())
print('    Cantidad cuadras:', dataset2018['id_cuadra'].drop_duplicates().count())
print()
print('dataset web scraping:')
print('    id_cuadra maximo:', dataset_ws.id_cuadra.max())
print('    Cantidad cuadras:', dataset_ws['id_cuadra'].drop_duplicates().count())
print()
print('dataset 2019:')
print('    id_cuadra maximo:', dataset2019.id_cuadra.max())
print('    Cantidad cuadras:', dataset2019['id_cuadra'].drop_duplicates().count())
# Out:
# dataset 2018:
#     id_cuadra maximo: 92
#     Cantidad cuadras: 90
#
# dataset web scraping:
#     id_cuadra maximo: 99
#     Cantidad cuadras: 97
#
# dataset 2019:
#     id_cuadra maximo: 190
#     Cantidad cuadras: 97

# %% [markdown]
# ## Que calle corresponde a cada ID

# %%
def merge_values(df1, df2, df3, not_on, on='id_cuadra', names=['2018_', 'ws_', '2019_']):
    '''
    Merge three df values to have a column output
    '''
    d1 = df1.copy()
    d2 = df2.copy()
    d3 = df3.copy()
    
    for name in not_on:
        d1.rename({name: (names[0]+name)}, axis=1, inplace=True)
        d2.rename({name: (names[1]+name)}, axis=1, inplace=True)
        d3.rename({name: (names[2]+name)}, axis=1, inplace=True)

    out = d1.merge(d2, on=on, how='outer')
    out = out.merge(d3, on=on, how='outer')
    return out.sort_values(by=on).reset_index(drop=True)

# %%
df1 = dataset2018[['id_cuadra', 'direccion']].drop_duplicates().sort_values(by='id_cuadra').reset_index(drop=True)
df2 = dataset_ws[['id_cuadra', 'direccion']].drop_duplicates().sort_values(by='id_cuadra').reset_index(drop=True)
df3 = dataset2019[['id_cuadra', 'direccion']].drop_duplicates().sort_values(by='id_cuadra').reset_index(drop=True)

display(merge_values(df1, df2, df3, not_on=['direccion'], on=['id_cuadra'])[0:])
# Out:
#      id_cuadra            2018_direccion              ws_direccion  \
# 0            0                       NaN                       NaN
# 1            1                       NaN                       NaN
# 2            2         General Pinto 545         General Pinto 545
# 3            3            San Martín 452            San Martín 452
# 4            4             Rodriguez 552             Rodriguez 552
# 5            5            9 de Julio 441            9 de Julio 441
# 6            6         General Pinto 759         General Pinto 759
# 7            7            San Martín 758            San Martín 758
# 8            8             Sarmiento 641             Sarmiento 641
# 9            9            San Martín 560            San Martín 560
# 10          10             Rodriguez 654             Rodriguez 654
# 11          11            San Martín 658            San Martín 658
# 12          12              Belgrano 480              Belgrano 480
# 13          13         General Pinto 343         General Pinto 343
# 14          14             Rodriguez 464             Rodriguez 464
# 15          15         General Pinto 631         General Pinto 631
# 16          16            San Martín 852            San Martín 852
# 17          17              Belgrano 660              Belgrano 660
# 18          18                       NaN                       NaN
# 19          19             Sarmiento 543             Sarmiento 543
# 20          20         General Pinto 490         General Pinto 490
# 21          21              Belgrano 540              Belgrano 540
# 22          22              Belgrano 768              Belgrano 768
# 23          23              Belgrano 364              Belgrano 364
# 24          24              Belgrano 868              Belgrano 868
# 25          25              Belgrano 958              Belgrano 958
# 26          26            9 de Julio 345            9 de Julio 345
# 27          27         General Pinto 843         General Pinto 843
# 28          28         General Pinto 945         General Pinto 945
# 29          29            San Martín 364            San Martín 364
# 30          30            San Martín 944            San Martín 944
# 31          31             Sarmiento 351             Sarmiento 351
# 32          32             Sarmiento 453             Sarmiento 453
# 33          33             Sarmiento 755             Sarmiento 755
# 34          34             Sarmiento 849             Sarmiento 849
# 35          35             Sarmiento 945             Sarmiento 945
# 36          36                 Mitre 758                 Mitre 758
# 37          37                 Mitre 846                 Mitre 846
# 38          38                 Mitre 948                 Mitre 948
# 39          39             Chacabuco 442             Chacabuco 442
# 40          40                 Mitre 348                 Mitre 348
# 41          41                 Mitre 446                 Mitre 446
# 42          42                 Mitre 552                 Mitre 552
# 43          43                 Mitre 648                 Mitre 648
# 44          44                  Alem 362                  Alem 362
# 45          45                  Alem 480                  Alem 480
# 46          46                  Alem 556                  Alem 556
# 47          47                  Alem 658                  Alem 658
# 48          48                  Alem 770                  Alem 770
# 49          49                  Alem 852                  Alem 852
# 50          50              Oficina SUMO              Oficina SUMO
# 51          51             Chacabuco 562             Chacabuco 562
# 52          52             Chacabuco 646             Chacabuco 646
# 53          53             Chacabuco 752             Chacabuco 752
# 54          54             Chacabuco 852             Chacabuco 852
# 55          55           14 de Julio 467           14 de Julio 467
# 56          56              Yrigoyen 557              Yrigoyen 557
# 57          57              Yrigoyen 753              Yrigoyen 753
# 58          58              Yrigoyen 847              Yrigoyen 847
# 59          59              Yrigoyen 655              Yrigoyen 655
# 60          60  Fuerte Independencia 349  Fuerte Independencia 349
# 61          61             Chacabuco 357             Chacabuco 357
# 62          62            9 de Julio 753            9 de Julio 753
# 63          63            9 de Julio 843            9 de Julio 843
# 64          64             Rodriguez 348             Rodriguez 348
# 65          65             Rodriguez 746             Rodriguez 746
# 66          66             Rodriguez 846             Rodriguez 846
# 67          67           14 de Julio 347           14 de Julio 347
# 68          68           14 de Julio 557           14 de Julio 557
# 69          69           14 de Julio 657           14 de Julio 657
# 70          70           14 de Julio 767           14 de Julio 767
# 71          71           14 de Julio 847           14 de Julio 847
# 72          72                 Maipu 453                 Maipu 453
# 73          73                 Maipu 547                 Maipu 547
# 74          74                 Maipu 653                 Maipu 653
# 75          75                 Maipu 333                 Maipu 333
# 76          76                 Maipu 741                 Maipu 741
# 77          77                 Maipu 857                 Maipu 857
# 78          78                 Maipu 953                 Maipu 953
# 79          79           General Paz 347           General Paz 347
# 80          80           General Paz 447           General Paz 447
# 81          81           General Paz 547           General Paz 547
# 82          82           General Paz 647           General Paz 647
# 83          83           General Paz 739           General Paz 739
# 84          84           General Paz 845           General Paz 845
# 85          85            Av. España 359            Av. España 359
# 86          86            Av. España 481            Av. España 481
# 87          87            Av. España 545            Av. España 545
# 88          88            Av. España 647            Av. España 647
# 89          89            Av. España 737            Av. España 737
# 90          90            Av. España 843            Av. España 843
# 91          91            Av. España 957            Av. España 957
# 92          92        Tribunal de Faltas        Tribunal de Faltas
# 93          93                       NaN            Av. España 352
# 94          94                       NaN            Av. España 436
# 95          95                       NaN            Av. España 526
# 96          96                       NaN            Av. España 624
# 97          97                       NaN            Av. España 774
# 98          98                       NaN            Av. España 864
# 99          99                       NaN            Av. España 970
# 100        190                       NaN                       NaN
#
#                2019_direccion
# 0                Belgrano 768
# 1           General Pinto 545
# 2              San Martín 452
# 3               Rodriguez 552
# 4              9 de Julio 441
# 5           General Pinto 759
# 6              San Martín 758
# 7               Sarmiento 641
# 8              San Martín 560
# 9               Rodriguez 654
# 10             San Martín 658
# 11               Belgrano 480
# 12          General Pinto 343
# 13              Rodriguez 464
# 14          General Pinto 631
# 15             San Martín 852
# 16               Belgrano 660
# 17              Sarmiento 849
# 18              Sarmiento 543
# 19          General Pinto 490
# 20               Belgrano 540
# 21          General Pinto 945
# 22              Sarmiento 453
# 23                  Mitre 758
# 24               Belgrano 364
# 25                   Alem 658
# 26                   Alem 362
# 27                  Mitre 648
# 28               Belgrano 868
# 29                   Alem 480
# 30                   Alem 770
# 31             San Martín 944
# 32              Sarmiento 755
# 33             San Martín 364
# 34              Sarmiento 351
# 35                   Alem 852
# 36               Belgrano 958
# 37               Oficina SUMO
# 38               Yrigoyen 753
# 39          General Pinto 843
# 40                   Alem 556
# 41              Sarmiento 945
# 42                  Mitre 948
# 43             9 de Julio 345
# 44                  Mitre 446
# 45              Chacabuco 442
# 46                  Mitre 348
# 47                  Mitre 846
# 48                  Mitre 552
# 49              Chacabuco 646
# 50              Chacabuco 752
# 51              Chacabuco 852
# 52            14 de Julio 847
# 53              Chacabuco 562
# 54            14 de Julio 467
# 55   Fuerte Independencia 349
# 56               Yrigoyen 557
# 57             9 de Julio 753
# 58               Yrigoyen 655
# 59             9 de Julio 843
# 60              Chacabuco 357
# 61               Yrigoyen 847
# 62                  Maipu 653
# 63            14 de Julio 767
# 64                  Maipu 453
# 65              Rodriguez 348
# 66            14 de Julio 347
# 67              Rodriguez 846
# 68              Rodriguez 746
# 69                  Maipu 547
# 70            14 de Julio 657
# 71            14 de Julio 557
# 72            General Paz 447
# 73            General Paz 647
# 74                  Maipu 857
# 75            General Paz 845
# 76            General Paz 547
# 77                  Maipu 953
# 78            General Paz 739
# 79                  Maipu 333
# 80            General Paz 347
# 81                  Maipu 741
# 82             Av. España 481
# 83                        NaN
# 84             Av. España 647
# 85             Av. España 545
# 86             Av. España 957
# 87             Av. España 359
# 88             Av. España 843
# 89             Av. España 737
# 90             Av. España 970
# 91             Av. España 864
# 92             Av. España 774
# 93             Av. España 624
# 94             Av. España 526
# 95             Av. España 436
# 96             Av. España 352
# 97                        NaN
# 98                        NaN
# 99                        NaN
# 100        Tribunal de Faltas

# %% [markdown]
# ## Cuanta ocupación máxima han tenido y cuanta en promedio (promedio de los maximos de cada dia) por calle

# %%
def get_parking_lots(data):
    '''
    
    '''
    d = data.copy()
    max_parking_lots = d[['direccion', 'fecha','ocupacion']].groupby(by=['direccion','fecha']).max().reset_index().groupby(by=['direccion']).max().reset_index()[['direccion', 'ocupacion']]
    max_parking_lots.rename(columns={'ocupacion': 'Cantidad maxima de estacionados'}, inplace=True)

    mean_max_parking_lots = d[['direccion','fecha', 'ocupacion']].groupby(by=['direccion','fecha']).max().reset_index().groupby(by=['direccion']).mean().reset_index()[['direccion','ocupacion']]
    mean_max_parking_lots.rename(columns={'ocupacion': 'Cantidad promedio de estacionados'}, inplace=True)
        
    return max_parking_lots.merge(mean_max_parking_lots, on=['direccion'])

# %%
dataset2018_parkinglots = get_parking_lots(dataset2018).sort_values(by='Cantidad maxima de estacionados', ascending=False).reset_index(drop=True)
dataset_ws_parkinglots = get_parking_lots(dataset_ws).sort_values(by='Cantidad maxima de estacionados', ascending=False).reset_index(drop=True)
dataset2019_parkinglots = get_parking_lots(dataset2019).sort_values(by='Cantidad maxima de estacionados', ascending=False).reset_index(drop=True)

# %%
display(dataset2018_parkinglots)
# Out:
# dataset2018                 direccion  Cantidad maxima de estacionados  \
# 0                        Yrigoyen 655                               27
# 1                   General Pinto 545                               26
# 2                      San Martín 658                               24
# 3                     General Paz 447                               22
# 4                       Sarmiento 755                               20
# 5                       Rodriguez 464                               20
# 6            Fuerte Independencia 349                               20
# 7                        Belgrano 540                               19
# 8                   General Pinto 343                               19
# 9                        Yrigoyen 847                               19
# 10                      Chacabuco 442                               18
# 11                          Maipu 741                               18
# 12                       Yrigoyen 557                               18
# 13                      Sarmiento 453                               18
# 14                       Belgrano 768                               18
# 15                     9 de Julio 441                               18
# 16                      Sarmiento 849                               17
# 17                  General Pinto 631                               17
# 18                     San Martín 852                               17
# 19                           Alem 480                               17
# 20                      Rodriguez 552                               17
# 21                    General Paz 647                               16
# 22                  General Pinto 759                               16
# 23                          Maipu 333                               16
# 24                      Sarmiento 543                               16
# 25                      Sarmiento 641                               16
# 26                       Yrigoyen 753                               16
# 27                          Maipu 453                               15
# 28                     San Martín 560                               15
# 29                  General Pinto 843                               15
# 30                     San Martín 944                               15
# 31                      Rodriguez 654                               15
# 32                           Alem 362                               15
# 33                       Belgrano 660                               15
# 34                       Belgrano 868                               15
# 35                          Mitre 948                               14
# 36                          Maipu 653                               14
# 37                      Chacabuco 562                               14
# 38                      Rodriguez 746                               14
# 39                      Chacabuco 646                               13
# 40                           Alem 556                               13
# 41                           Alem 770                               13
# 42                      Chacabuco 357                               13
# 43                       Belgrano 480                               13
# 44                  General Pinto 490                               13
# 45                     San Martín 364                               12
# 46                      Rodriguez 348                               12
# 47                     San Martín 452                               12
# 48                     San Martín 758                               12
# 49                      Sarmiento 945                               12
# 50                          Maipu 547                               12
# 51                    14 de Julio 347                               12
# 52                      Chacabuco 852                               11
# 53                           Alem 658                               11
# 54                     9 de Julio 753                               11
# 55                      Sarmiento 351                               11
# 56                          Mitre 648                               11
# 57                          Mitre 846                               11
# 58                    General Paz 547                               11
# 59                     Av. España 737                               11
# 60                    General Paz 739                               11
# 61                      Rodriguez 846                               11
# 62                    General Paz 845                               10
# 63                     9 de Julio 345                               10
# 64                          Maipu 857                               10
# 65                    14 de Julio 557                               10
# 66                      Chacabuco 752                               10
# 67                  General Pinto 945                               10
# 68                          Mitre 758                                9
# 69                    14 de Julio 847                                9
# 70                    14 de Julio 467                                9
# 71                       Belgrano 364                                9
# 72                       Belgrano 958                                9
# 73                          Mitre 446                                9
# 74                          Mitre 552                                9
# 75                     9 de Julio 843                                8
# 76                       Oficina SUMO                                8
# 77                          Mitre 348                                8
# 78                    General Paz 347                                8
# 79                           Alem 852                                7
# 80                    14 de Julio 657                                7
# 81                     Av. España 843                                7
# 82                     Av. España 957                                7
# 83                     Av. España 481                                7
# 84                     Av. España 545                                6
# 85                     Av. España 647                                6
# 86                     Av. España 359                                5
# 87                          Maipu 953                                5
# 88                    14 de Julio 767                                5
# 89                 Tribunal de Faltas                                1
#
# dataset2018  Cantidad promedio de estacionados
# 0                                    12.821429
# 1                                     8.972414
# 2                                    11.233577
# 3                                    10.908451
# 4                                     9.953947
# 5                                     8.379845
# 6                                     6.374101
# 7                                     9.808333
# 8                                     8.527132
# 9                                     8.984733
# 10                                    7.171429
# 11                                    7.963768
# 12                                    9.955882
# 13                                    8.742857
# 14                                    7.879195
# 15                                    9.067568
# 16                                    8.138889
# 17                                    7.856164
# 18                                    7.391304
# 19                                    9.342857
# 20                                    7.898649
# 21                                    7.390071
# 22                                    8.612676
# 23                                    7.593750
# 24                                    6.790210
# 25                                    6.881944
# 26                                    8.792857
# 27                                    6.395683
# 28                                    6.228571
# 29                                    8.384058
# 30                                    8.473684
# 31                                    7.275862
# 32                                    7.404580
# 33                                    7.865248
# 34                                    6.755396
# 35                                    6.398496
# 36                                    6.474453
# 37                                    7.649635
# 38                                    7.395683
# 39                                    6.914286
# 40                                    8.092199
# 41                                    5.808511
# 42                                    6.435714
# 43                                    5.942446
# 44                                    6.843284
# 45                                    4.842520
# 46                                    5.468966
# 47                                    5.584615
# 48                                    6.985612
# 49                                    6.167883
# 50                                    4.712121
# 51                                    5.260504
# 52                                    3.985185
# 53                                    6.145833
# 54                                    6.226277
# 55                                    5.696296
# 56                                    4.976744
# 57                                    5.875912
# 58                                    5.816176
# 59                                    4.984848
# 60                                    6.262774
# 61                                    5.234483
# 62                                    4.183673
# 63                                    5.297101
# 64                                    3.492063
# 65                                    3.780303
# 66                                    5.088235
# 67                                    4.437037
# 68                                    5.094891
# 69                                    1.878505
# 70                                    3.823077
# 71                                    3.861314
# 72                                    3.057851
# 73                                    3.867647
# 74                                    5.014815
# 75                                    3.687943
# 76                                    3.352000
# 77                                    2.688000
# 78                                    2.539062
# 79                                    3.559055
# 80                                    2.840909
# 81                                    2.860140
# 82                                    2.890511
# 83                                    2.039370
# 84                                    2.447154
# 85                                    2.636364
# 86                                    1.393443
# 87                                    1.909091
# 88                                    2.536364
# 89                                    1.000000

# %%
display(dataset_ws_parkinglots)
# Out:
# dataset_ws                 direccion  Cantidad maxima de estacionados  \
# 0                       Yrigoyen 655                               42
# 1           Fuerte Independencia 349                               29
# 2                          Maipu 453                               27
# 3                      Rodriguez 464                               27
# 4                          Maipu 333                               27
# 5                      Sarmiento 453                               27
# 6                      Sarmiento 755                               26
# 7                    General Paz 647                               26
# 8                       Belgrano 540                               26
# 9                  General Pinto 759                               24
# 10                     Rodriguez 552                               24
# 11                    San Martín 658                               24
# 12                 General Pinto 343                               23
# 13                      Belgrano 480                               23
# 14                      Yrigoyen 847                               23
# 15                         Mitre 648                               22
# 16                    San Martín 944                               22
# 17                   General Paz 447                               22
# 18                   14 de Julio 847                               22
# 19                         Maipu 741                               22
# 20                      Yrigoyen 753                               22
# 21                     Chacabuco 442                               22
# 22                   14 de Julio 767                               21
# 23                         Mitre 348                               21
# 24                          Alem 480                               21
# 25                     Sarmiento 849                               21
# 26                     Chacabuco 752                               21
# 27                    9 de Julio 441                               21
# 28                      Belgrano 660                               21
# 29                      Belgrano 768                               21
# 30                 General Pinto 545                               20
# 31                 General Pinto 490                               20
# 32                         Maipu 547                               20
# 33                     Chacabuco 357                               20
# 34                 General Pinto 843                               20
# 35                      Yrigoyen 557                               20
# 36                     Rodriguez 654                               20
# 37                          Alem 362                               20
# 38                     Rodriguez 746                               20
# 39                    9 de Julio 753                               19
# 40                         Mitre 552                               19
# 41                 General Pinto 631                               19
# 42                          Alem 556                               19
# 43                    San Martín 852                               18
# 44                     Chacabuco 562                               18
# 45                     Chacabuco 646                               18
# 46                     Sarmiento 543                               18
# 47                     Sarmiento 641                               17
# 48                          Alem 658                               17
# 49                     Sarmiento 351                               17
# 50                          Alem 770                               17
# 51                    San Martín 758                               17
# 52                         Maipu 653                               17
# 53                    San Martín 452                               17
# 54                         Mitre 846                               16
# 55                    San Martín 364                               16
# 56                    San Martín 560                               16
# 57                   14 de Julio 347                               16
# 58                   General Paz 739                               16
# 59                    Av. España 843                               15
# 60                     Rodriguez 348                               15
# 61                         Mitre 948                               15
# 62                         Mitre 758                               15
# 63                     Chacabuco 852                               14
# 64                   General Paz 845                               14
# 65                     Rodriguez 846                               14
# 66                   General Paz 547                               14
# 67                    9 de Julio 345                               13
# 68                     Sarmiento 945                               13
# 69                    Av. España 957                               13
# 70                    Av. España 737                               13
# 71                         Mitre 446                               12
# 72                   General Paz 347                               12
# 73                      Belgrano 868                               12
# 74                          Alem 852                               12
# 75                    Av. España 526                               11
# 76                   14 de Julio 557                               11
# 77                      Belgrano 364                               11
# 78                    Av. España 970                               11
# 79                    9 de Julio 843                               11
# 80                   14 de Julio 467                               11
# 81                    Av. España 774                               11
# 82                 General Pinto 945                               10
# 83                    Av. España 864                               10
# 84                   14 de Julio 657                                9
# 85                    Av. España 545                                8
# 86                    Av. España 481                                8
# 87                      Belgrano 958                                8
# 88                    Av. España 624                                7
# 89                    Av. España 352                                7
# 90                         Maipu 857                                7
# 91                      Oficina SUMO                                7
# 92                    Av. España 647                                7
# 93                         Maipu 953                                6
# 94                    Av. España 359                                5
# 95                    Av. España 436                                4
# 96                Tribunal de Faltas                                1
#
# dataset_ws  Cantidad promedio de estacionados
# 0                                   21.811321
# 1                                   14.490196
# 2                                   11.058824
# 3                                   10.596154
# 4                                   15.591837
# 5                                   15.596154
# 6                                   16.698113
# 7                                   12.557692
# 8                                   14.127273
# 9                                   14.519231
# 10                                  15.407407
# 11                                  15.962963
# 12                                  14.230769
# 13                                   9.962264
# 14                                  12.240741
# 15                                  10.339623
# 16                                  12.862745
# 17                                  13.254902
# 18                                   6.291667
# 19                                  11.780000
# 20                                  14.339623
# 21                                  11.843137
# 22                                   5.065217
# 23                                   6.428571
# 24                                  13.549020
# 25                                  13.250000
# 26                                  10.096154
# 27                                  12.490196
# 28                                  12.773585
# 29                                  13.215686
# 30                                  12.462963
# 31                                  10.489796
# 32                                   8.500000
# 33                                  12.907407
# 34                                  12.519231
# 35                                  13.592593
# 36                                  10.625000
# 37                                  11.254902
# 38                                  12.245283
# 39                                  11.358491
# 40                                  10.166667
# 41                                  11.607843
# 42                                  12.698113
# 43                                   9.851852
# 44                                  10.333333
# 45                                   9.788462
# 46                                  11.132075
# 47                                  10.941176
# 48                                   9.905660
# 49                                   9.260000
# 50                                   9.692308
# 51                                  10.723404
# 52                                   9.220000
# 53                                   9.509434
# 54                                   8.788462
# 55                                   8.437500
# 56                                   8.634615
# 57                                   8.375000
# 58                                   9.960784
# 59                                   6.100000
# 60                                   9.207547
# 61                                   9.187500
# 62                                   8.301887
# 63                                   6.551020
# 64                                   7.698113
# 65                                   8.647059
# 66                                   8.500000
# 67                                   8.156863
# 68                                   9.196078
# 69                                   5.098039
# 70                                   8.254902
# 71                                   5.444444
# 72                                   3.914894
# 73                                   6.916667
# 74                                   5.745098
# 75                                   4.152174
# 76                                   6.140000
# 77                                   5.962963
# 78                                   5.177778
# 79                                   7.192308
# 80                                   5.528302
# 81                                   6.320000
# 82                                   5.460000
# 83                                   5.666667
# 84                                   4.549020
# 85                                   3.897959
# 86                                   3.938776
# 87                                   4.020833
# 88                                   4.265306
# 89                                   2.127660
# 90                                   3.787234
# 91                                   3.659574
# 92                                   4.264151
# 93                                   3.045455
# 94                                   2.804348
# 95                                   2.148936
# 96                                   0.500000

# %%
display(dataset2019_parkinglots)
# Out:
# dataset2019                 direccion  Cantidad maxima de estacionados  \
# 0                       Sarmiento 755                               49
# 1                      San Martín 658                               47
# 2                       Rodriguez 654                               45
# 3                        Belgrano 660                               45
# 4            Fuerte Independencia 349                               43
# 5                        Yrigoyen 655                               41
# 6                   General Pinto 759                               40
# 7                       Sarmiento 849                               38
# 8                      San Martín 560                               37
# 9                      San Martín 852                               36
# 10                          Maipu 453                               34
# 11                      Rodriguez 746                               34
# 12                      Rodriguez 552                               33
# 13                          Maipu 333                               33
# 14                  General Pinto 343                               32
# 15                      Sarmiento 543                               32
# 16                  General Pinto 631                               32
# 17                  General Pinto 490                               31
# 18                       Belgrano 540                               30
# 19                    General Paz 647                               30
# 20                       Belgrano 768                               29
# 21                      Sarmiento 453                               28
# 22                     San Martín 758                               28
# 23                           Alem 480                               28
# 24                  General Pinto 545                               27
# 25                      Chacabuco 357                               27
# 26                    General Paz 447                               27
# 27                      Sarmiento 641                               27
# 28                      Rodriguez 464                               27
# 29                     9 de Julio 753                               27
# 30                     San Martín 452                               26
# 31                  General Pinto 843                               26
# 32                      Chacabuco 442                               26
# 33                       Belgrano 480                               25
# 34                     9 de Julio 441                               25
# 35                       Yrigoyen 847                               24
# 36                      Chacabuco 752                               24
# 37                       Yrigoyen 753                               23
# 38                       Yrigoyen 557                               23
# 39                           Alem 658                               23
# 40                           Alem 556                               23
# 41                     San Martín 944                               23
# 42                          Mitre 648                               23
# 43                          Maipu 741                               22
# 44                     San Martín 364                               22
# 45                          Mitre 348                               22
# 46                    General Paz 739                               22
# 47                           Alem 362                               22
# 48                    14 de Julio 347                               21
# 49                      Chacabuco 562                               21
# 50                    14 de Julio 847                               21
# 51                          Maipu 547                               21
# 52                          Maipu 857                               20
# 53                          Mitre 552                               20
# 54                    14 de Julio 767                               20
# 55                      Chacabuco 646                               19
# 56                       Belgrano 868                               19
# 57                          Mitre 758                               19
# 58                     9 de Julio 345                               19
# 59                     Av. España 737                               19
# 60                          Mitre 948                               19
# 61                          Mitre 846                               19
# 62                       Belgrano 364                               19
# 63                      Sarmiento 351                               18
# 64                          Maipu 653                               18
# 65                       Oficina SUMO                               18
# 66                           Alem 770                               17
# 67                      Rodriguez 348                               17
# 68                    General Paz 845                               17
# 69                    General Paz 547                               16
# 70                      Chacabuco 852                               16
# 71                      Rodriguez 846                               16
# 72                      Sarmiento 945                               15
# 73                     Av. España 957                               15
# 74                     9 de Julio 843                               15
# 75                           Alem 852                               15
# 76                          Mitre 446                               14
# 77                    14 de Julio 557                               14
# 78                     Av. España 843                               14
# 79                     Av. España 774                               14
# 80                     Av. España 864                               13
# 81                    14 de Julio 467                               13
# 82                  General Pinto 945                               12
# 83                       Belgrano 958                               12
# 84                    General Paz 347                               11
# 85                     Av. España 970                               11
# 86                     Av. España 526                               10
# 87                    14 de Julio 657                               10
# 88                     Av. España 647                               10
# 89                     Av. España 481                               10
# 90                     Av. España 545                               10
# 91                     Av. España 624                                9
# 92                          Maipu 953                                9
# 93                     Av. España 352                                7
# 94                     Av. España 436                                7
# 95                     Av. España 359                                7
# 96                 Tribunal de Faltas                                2
#
# dataset2019  Cantidad promedio de estacionados
# 0                                    21.746269
# 1                                    18.426380
# 2                                    13.201258
# 3                                    16.933735
# 4                                    12.375394
# 5                                    18.931250
# 6                                    18.098462
# 7                                    14.612698
# 8                                    12.106061
# 9                                    11.840532
# 10                                   11.287066
# 11                                   15.861538
# 12                                   15.179012
# 13                                   14.883281
# 14                                   13.440972
# 15                                   12.064815
# 16                                   14.339506
# 17                                   12.828571
# 18                                   13.277946
# 19                                   12.246795
# 20                                   12.765273
# 21                                   13.292994
# 22                                   11.805643
# 23                                   11.765432
# 24                                   12.702128
# 25                                   12.209440
# 26                                   12.401961
# 27                                   11.658385
# 28                                   12.091195
# 29                                   11.487261
# 30                                    9.319489
# 31                                   12.115987
# 32                                   11.996825
# 33                                    9.642633
# 34                                   12.506579
# 35                                   11.651316
# 36                                    9.140523
# 37                                   11.705128
# 38                                   12.773292
# 39                                   10.188088
# 40                                   11.987461
# 41                                   11.734899
# 42                                   10.281457
# 43                                   10.621019
# 44                                    8.056291
# 45                                    5.107266
# 46                                    9.501629
# 47                                   10.389068
# 48                                    8.246377
# 49                                    9.617647
# 50                                    3.333333
# 51                                    7.835526
# 52                                    3.516667
# 53                                    9.058632
# 54                                    4.209622
# 55                                   10.067524
# 56                                    7.495114
# 57                                    7.922330
# 58                                    8.445860
# 59                                    8.006601
# 60                                    8.279743
# 61                                    7.980456
# 62                                    5.896440
# 63                                    8.794872
# 64                                    8.535256
# 65                                    6.489655
# 66                                    8.993590
# 67                                    8.760252
# 68                                    7.177994
# 69                                    7.961165
# 70                                    6.227564
# 71                                    8.093093
# 72                                    8.060317
# 73                                    5.217252
# 74                                    7.006515
# 75                                    5.983871
# 76                                    5.934708
# 77                                    5.747508
# 78                                    5.416393
# 79                                    6.378378
# 80                                    5.399317
# 81                                    5.580537
# 82                                    5.517572
# 83                                    4.267559
# 84                                    3.867987
# 85                                    4.656140
# 86                                    4.185185
# 87                                    4.240000
# 88                                    4.635484
# 89                                    3.891089
# 90                                    4.032468
# 91                                    4.141818
# 92                                    2.742958
# 93                                    2.215017
# 94                                    2.195489
# 95                                    2.737201
# 96                                    0.934783

# %% [markdown]
# ## En que momento fueron esos maximos

# %%
def get_date_of_max_parking_lots(df, max_parking_lots):
    d = df.copy()
    
    out = pd.DataFrame(columns=['direccion', 'fecha', 'ocupacion'])
    for s in max_parking_lots['direccion']:
        to_add = d.loc[d['direccion'] == s]
        max_for_street = max_parking_lots.loc[max_parking_lots['direccion'] == s]
        
        to_add = to_add.loc[to_add.ocupacion == max_for_street['Cantidad maxima de estacionados'].iloc[0], ['direccion', 'fecha', 'ocupacion']].iloc[0]
        out = out.append(to_add)
    
    return out.sort_values(by='ocupacion').reset_index(drop=True)

# %%
get_date_of_max_parking_lots(dataset2018, dataset2018_parkinglots)
# Out:
#                    direccion       fecha ocupacion
# 0         Tribunal de Faltas  2018-05-28         1
# 1             Av. España 359  2018-06-11         5
# 2            14 de Julio 767  2018-03-05         5
# 3                  Maipu 953  2018-06-06         5
# 4             Av. España 647  2018-05-23         6
# 5             Av. España 545  2018-03-22         6
# 6             Av. España 481  2018-06-11         7
# 7             Av. España 957  2018-06-05         7
# 8             Av. España 843  2018-03-22         7
# 9            14 de Julio 657  2018-03-06         7
# 10                  Alem 852  2018-02-27         7
# 11              Oficina SUMO  2018-06-01         8
# 12            9 de Julio 843  2018-01-30         8
# 13           General Paz 347  2018-06-04         8
# 14                 Mitre 348  2018-05-30         8
# 15                 Mitre 446  2018-05-05         9
# 16              Belgrano 958  2018-01-05         9
# 17              Belgrano 364  2018-06-05         9
# 18           14 de Julio 467  2018-05-23         9
# 19           14 de Julio 847  2018-05-11         9
# 20                 Mitre 758  2018-03-08         9
# 21                 Mitre 552  2018-01-16         9
# 22            9 de Julio 345  2018-04-05        10
# 23           General Paz 845  2018-06-05        10
# 24           14 de Julio 557  2018-03-13        10
# 25             Chacabuco 752  2018-03-28        10
# 26         General Pinto 945  2018-05-11        10
# 27                 Maipu 857  2018-05-18        10
# 28             Chacabuco 852  2018-06-13        11
# 29                  Alem 658  2018-06-01        11
# 30             Sarmiento 351  2018-01-02        11
# 31                 Mitre 648  2018-06-02        11
# 32            9 de Julio 753  2018-01-02        11
# 33           General Paz 547  2018-02-14        11
# 34            Av. España 737  2018-06-11        11
# 35           General Paz 739  2018-03-13        11
# 36             Rodriguez 846  2018-05-10        11
# 37                 Mitre 846  2018-03-09        11
# 38           14 de Julio 347  2018-05-31        12
# 39                 Maipu 547  2018-06-13        12
# 40             Sarmiento 945  2018-06-04        12
# 41            San Martín 758  2018-04-12        12
# 42            San Martín 452  2018-03-28        12
# 43             Rodriguez 348  2018-06-11        12
# 44            San Martín 364  2018-02-16        12
# 45         General Pinto 490  2018-03-07        13
# 46             Chacabuco 357  2018-06-04        13
# 47                  Alem 770  2018-03-08        13
# 48                  Alem 556  2018-02-28        13
# 49             Chacabuco 646  2018-04-05        13
# 50              Belgrano 480  2018-01-29        13
# 51             Rodriguez 746  2018-02-27        14
# 52             Chacabuco 562  2018-02-05        14
# 53                 Maipu 653  2018-02-16        14
# 54                 Mitre 948  2018-05-03        14
# 55                 Maipu 453  2018-06-05        15
# 56            San Martín 560  2018-04-23        15
# 57         General Pinto 843  2018-05-07        15
# 58              Belgrano 660  2018-01-24        15
# 59             Rodriguez 654  2018-05-09        15
# 60                  Alem 362  2018-01-08        15
# 61              Belgrano 868  2018-03-05        15
# 62            San Martín 944  2018-03-01        15
# 63         General Pinto 759  2018-06-01        16
# 64                 Maipu 333  2018-02-27        16
# 65           General Paz 647  2018-03-02        16
# 66             Sarmiento 641  2018-01-04        16
# 67              Yrigoyen 753  2018-06-01        16
# 68             Sarmiento 543  2018-06-13        16
# 69             Rodriguez 552  2018-05-23        17
# 70                  Alem 480  2018-03-06        17
# 71            San Martín 852  2018-05-24        17
# 72         General Pinto 631  2018-05-29        17
# 73             Sarmiento 849  2018-04-13        17
# 74             Chacabuco 442  2018-05-24        18
# 75              Yrigoyen 557  2018-06-01        18
# 76                 Maipu 741  2018-03-05        18
# 77              Belgrano 768  2018-06-04        18
# 78            9 de Julio 441  2018-05-03        18
# 79             Sarmiento 453  2018-06-13        18
# 80              Yrigoyen 847  2018-05-23        19
# 81         General Pinto 343  2018-06-11        19
# 82              Belgrano 540  2018-02-14        19
# 83  Fuerte Independencia 349  2018-05-23        20
# 84             Rodriguez 464  2018-06-13        20
# 85             Sarmiento 755  2018-01-04        20
# 86           General Paz 447  2018-04-03        22
# 87            San Martín 658  2018-05-26        24
# 88         General Pinto 545  2018-06-11        26
# 89              Yrigoyen 655  2018-06-07        27

# %%
get_date_of_max_parking_lots(dataset_ws, dataset_ws_parkinglots)
# Out:
#                    direccion       fecha ocupacion
# 0         Tribunal de Faltas  2019-09-12         1
# 1             Av. España 436  2019-09-11         4
# 2             Av. España 359  2019-09-18         5
# 3                  Maipu 953  2019-10-08         6
# 4               Oficina SUMO  2019-09-13         7
# 5                  Maipu 857  2019-10-18         7
# 6             Av. España 352  2019-09-27         7
# 7             Av. España 624  2019-09-25         7
# 8             Av. España 647  2019-09-11         7
# 9               Belgrano 958  2019-12-04         8
# 10            Av. España 481  2019-09-13         8
# 11            Av. España 545  2019-09-16         8
# 12           14 de Julio 657  2019-10-08         9
# 13         General Pinto 945  2019-11-08        10
# 14            Av. España 864  2019-09-16        10
# 15            Av. España 774  2019-11-29        11
# 16           14 de Julio 467  2019-10-15        11
# 17            9 de Julio 843  2019-11-29        11
# 18            Av. España 970  2019-11-27        11
# 19              Belgrano 364  2019-09-20        11
# 20           14 de Julio 557  2019-10-09        11
# 21            Av. España 526  2019-12-04        11
# 22                 Mitre 446  2019-10-23        12
# 23           General Paz 347  2019-09-17        12
# 24                  Alem 852  2019-10-18        12
# 25              Belgrano 868  2019-12-02        12
# 26            Av. España 737  2019-12-11        13
# 27            Av. España 957  2019-12-02        13
# 28             Sarmiento 945  2019-09-12        13
# 29            9 de Julio 345  2019-09-25        13
# 30           General Paz 547  2019-11-27        14
# 31             Rodriguez 846  2019-11-29        14
# 32           General Paz 845  2019-12-02        14
# 33             Chacabuco 852  2019-10-04        14
# 34            Av. España 843  2019-10-10        15
# 35             Rodriguez 348  2019-11-28        15
# 36                 Mitre 758  2019-09-16        15
# 37                 Mitre 948  2019-10-08        15
# 38           General Paz 739  2019-09-12        16
# 39           14 de Julio 347  2019-10-18        16
# 40            San Martín 560  2019-12-04        16
# 41            San Martín 364  2019-10-22        16
# 42                 Mitre 846  2019-11-27        16
# 43            San Martín 452  2019-11-29        17
# 44                 Maipu 653  2019-10-18        17
# 45            San Martín 758  2019-09-20        17
# 46                  Alem 770  2019-09-19        17
# 47             Sarmiento 351  2019-09-13        17
# 48                  Alem 658  2019-09-24        17
# 49             Sarmiento 641  2019-10-05        17
# 50             Sarmiento 543  2019-12-04        18
# 51             Chacabuco 646  2019-10-15        18
# 52             Chacabuco 562  2019-10-18        18
# 53            San Martín 852  2019-11-28        18
# 54                  Alem 556  2019-12-06        19
# 55         General Pinto 631  2019-10-18        19
# 56                 Mitre 552  2019-10-11        19
# 57            9 de Julio 753  2019-09-11        19
# 58         General Pinto 545  2019-10-11        20
# 59         General Pinto 490  2019-12-09        20
# 60                 Maipu 547  2019-12-02        20
# 61             Chacabuco 357  2019-09-17        20
# 62             Rodriguez 654  2019-09-21        20
# 63              Yrigoyen 557  2019-12-09        20
# 64                  Alem 362  2019-10-23        20
# 65             Rodriguez 746  2019-10-09        20
# 66         General Pinto 843  2019-10-09        20
# 67                  Alem 480  2019-09-25        21
# 68           14 de Julio 767  2019-09-27        21
# 69             Sarmiento 849  2019-12-04        21
# 70                 Mitre 348  2019-09-27        21
# 71            9 de Julio 441  2019-11-29        21
# 72              Belgrano 660  2019-10-04        21
# 73              Belgrano 768  2019-10-18        21
# 74             Chacabuco 752  2019-10-04        21
# 75             Chacabuco 442  2019-12-02        22
# 76              Yrigoyen 753  2019-10-10        22
# 77                 Maipu 741  2019-10-04        22
# 78           14 de Julio 847  2019-09-27        22
# 79           General Paz 447  2019-09-27        22
# 80            San Martín 944  2019-11-28        22
# 81                 Mitre 648  2019-11-29        22
# 82         General Pinto 343  2019-12-11        23
# 83              Yrigoyen 847  2019-12-09        23
# 84              Belgrano 480  2019-12-02        23
# 85            San Martín 658  2019-10-21        24
# 86             Rodriguez 552  2019-12-11        24
# 87         General Pinto 759  2019-10-04        24
# 88              Belgrano 540  2019-12-10        26
# 89           General Paz 647  2019-11-28        26
# 90             Sarmiento 755  2019-10-03        26
# 91             Sarmiento 453  2019-09-11        27
# 92                 Maipu 333  2019-10-07        27
# 93             Rodriguez 464  2019-09-13        27
# 94                 Maipu 453  2019-12-02        27
# 95  Fuerte Independencia 349  2019-09-27        29
# 96              Yrigoyen 655  2019-11-28        42

# %%
get_date_of_max_parking_lots(dataset2019, dataset2019_parkinglots)
# Out:
#                    direccion       fecha ocupacion
# 0         Tribunal de Faltas  2019-02-05         2
# 1             Av. España 352  2019-09-27         7
# 2             Av. España 359  2019-01-22         7
# 3             Av. España 436  2019-07-19         7
# 4                  Maipu 953  2019-11-26         9
# 5             Av. España 624  2019-04-09         9
# 6             Av. España 545  2019-08-09        10
# 7             Av. España 481  2019-06-10        10
# 8             Av. España 647  2019-08-09        10
# 9            14 de Julio 657  2019-04-29        10
# 10            Av. España 526  2019-06-21        10
# 11            Av. España 970  2019-10-16        11
# 12           General Paz 347  2019-03-01        11
# 13              Belgrano 958  2019-04-11        12
# 14         General Pinto 945  2019-05-24        12
# 15           14 de Julio 467  2019-05-02        13
# 16            Av. España 864  2019-10-22        13
# 17            Av. España 774  2019-09-18        14
# 18            Av. España 843  2019-03-19        14
# 19           14 de Julio 557  2019-08-16        14
# 20                 Mitre 446  2019-03-08        14
# 21            Av. España 957  2019-05-31        15
# 22             Sarmiento 945  2019-02-08        15
# 23                  Alem 852  2019-06-28        15
# 24            9 de Julio 843  2019-12-23        15
# 25             Chacabuco 852  2019-10-04        16
# 26             Rodriguez 846  2019-05-30        16
# 27           General Paz 547  2019-05-02        16
# 28           General Paz 845  2019-02-25        17
# 29             Rodriguez 348  2019-05-07        17
# 30                  Alem 770  2019-04-12        17
# 31              Oficina SUMO  2019-03-29        18
# 32                 Maipu 653  2019-06-24        18
# 33             Sarmiento 351  2019-04-26        18
# 34             Chacabuco 646  2019-06-03        19
# 35              Belgrano 868  2019-12-23        19
# 36                 Mitre 758  2019-01-31        19
# 37                 Mitre 948  2019-09-06        19
# 38            Av. España 737  2019-07-15        19
# 39                 Mitre 846  2019-06-26        19
# 40              Belgrano 364  2019-03-15        19
# 41            9 de Julio 345  2019-07-04        19
# 42           14 de Julio 767  2019-09-27        20
# 43                 Mitre 552  2019-05-30        20
# 44                 Maipu 857  2019-12-16        20
# 45                 Maipu 547  2019-12-12        21
# 46           14 de Julio 847  2019-05-24        21
# 47             Chacabuco 562  2019-12-20        21
# 48           14 de Julio 347  2019-07-04        21
# 49           General Paz 739  2019-12-12        22
# 50                 Mitre 348  2019-09-27        22
# 51            San Martín 364  2019-10-22        22
# 52                 Maipu 741  2019-10-04        22
# 53                  Alem 362  2019-01-14        22
# 54                 Mitre 648  2019-12-09        23
# 55            San Martín 944  2019-03-06        23
# 56                  Alem 556  2019-03-06        23
# 57                  Alem 658  2019-04-12        23
# 58              Yrigoyen 557  2019-07-17        23
# 59              Yrigoyen 753  2019-11-15        23
# 60             Chacabuco 752  2019-08-15        24
# 61              Yrigoyen 847  2019-11-22        24
# 62            9 de Julio 441  2019-06-12        25
# 63              Belgrano 480  2019-12-11        25
# 64             Chacabuco 442  2019-12-19        26
# 65         General Pinto 843  2019-12-19        26
# 66            San Martín 452  2019-12-19        26
# 67            9 de Julio 753  2019-03-08        27
# 68             Rodriguez 464  2019-01-28        27
# 69             Sarmiento 641  2019-12-19        27
# 70           General Paz 447  2019-12-13        27
# 71             Chacabuco 357  2019-12-18        27
# 72         General Pinto 545  2019-07-29        27
# 73             Sarmiento 453  2019-10-08        28
# 74                  Alem 480  2019-08-28        28
# 75            San Martín 758  2019-07-05        28
# 76              Belgrano 768  2019-06-07        29
# 77           General Paz 647  2019-05-24        30
# 78              Belgrano 540  2019-12-18        30
# 79         General Pinto 490  2019-07-19        31
# 80         General Pinto 631  2019-04-03        32
# 81             Sarmiento 543  2019-11-15        32
# 82         General Pinto 343  2019-06-11        32
# 83                 Maipu 333  2019-05-27        33
# 84             Rodriguez 552  2019-12-12        33
# 85                 Maipu 453  2019-12-12        34
# 86             Rodriguez 746  2019-09-18        34
# 87            San Martín 852  2019-03-06        36
# 88            San Martín 560  2019-05-17        37
# 89             Sarmiento 849  2019-11-27        38
# 90         General Pinto 759  2019-04-05        40
# 91              Yrigoyen 655  2019-12-04        41
# 92  Fuerte Independencia 349  2019-07-05        43
# 93              Belgrano 660  2019-12-19        45
# 94             Rodriguez 654  2019-12-23        45
# 95            San Martín 658  2019-12-23        47
# 96             Sarmiento 755  2019-06-14        49

# %% [markdown]
# ## Box plot solo del dataset2019 ya que es el mas completo

# %%
#Con los datos solo de la calle de mayor ocupación

plt.boxplot(dataset2019.loc[dataset2019['direccion'] == 'Sarmiento 755', 'ocupacion'])
plt.grid(axis='y')
plt.rcParams['figure.figsize'] = (4,8)
plt.show()

# %%
#Con los datos completos

b = plt.boxplot(dataset2019.ocupacion)
plt.grid(axis='y')
plt.rcParams['figure.figsize'] = (4,8)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15,8)

# %% [markdown]
# ## Grafico de barras por mes

# %%
def create_bar_graph_for_months(df, full_dataset, ocup_limit = 3):
    
    d = df.copy()
    d['fecha'] = d.fecha.apply(lambda x: x.month)
    d.rename({'fecha': 'mes'},  axis=1, inplace=True)
    d = d[['mes', 'ocupacion']]
    
    #Count data
    fd = full_dataset.copy()
    d1 = pd.DataFrame(columns=['fecha','ocupacion'])
    for s in df['direccion']:
        max_ocup = df.loc[df['direccion'] == s, 'ocupacion'].values[0]
        fd_street = fd.loc[fd['direccion'] == s, ['fecha', 'ocupacion']]
        fd_street = fd_street.loc[fd_street.ocupacion > max_ocup - ocup_limit]
        d1 = d1.append(fd_street)
    
    d1['fecha'] = d1.fecha.apply(lambda x: x.month)
    d1.rename({'fecha': 'mes'},  axis=1, inplace=True)
    d1 = d1[['mes', 'ocupacion']]
    d1 = d1.groupby(by=['mes']).count().reset_index()
    d1.rename({'ocupacion': 'cantidad de maximos totales'},  axis=1, inplace=True)

    #Mean parking lots data
    d2 = d.copy()
    #Handmade mean, because mean throws error
    d2 = d2.groupby(by='mes').sum().reset_index()
    d2['ocupacion'] = d.groupby(by='mes').sum().reset_index()['ocupacion']/d.groupby(by='mes').count().reset_index()['ocupacion']
    d2.rename({'ocupacion': 'promedio de los maximos'},  axis=1, inplace=True)
    
    #total operations made on each month
    d3 = full_dataset.copy()
    d3['fecha'] = d3.fecha.apply(lambda x: x.month)
    d3.rename({'fecha': 'mes'},  axis=1, inplace=True)
    d3 = d3[['mes', 'ocupacion']]
    d3 = d3.groupby(by=['mes']).count().reset_index()
    d3.rename({'ocupacion': 'operaciones totales'}, axis=1, inplace=True)
    
    #To plot graphs...
    ax = plt.subplot(111)
    ax.bar(d1['mes']-0.2, d1['cantidad de maximos totales'] / 50, width=0.2, color='brown')
    ax.bar(d2['mes'], d2['promedio de los maximos'], width=0.2, color='pink')
    ax.bar(d3['mes']+0.2, d3['operaciones totales'] / 10000, width=0.2, color='grey')
    
    plt.xlabel("Mes")
    plt.ylabel("")
    plt.title("")
    plt.legend(['Cantidad de maximos (1/50)', 'Promedio de maximos', 'Operaciones totales (1/10.000)'])

    plt.grid(axis='y')
    
    plt.show()

# %%
create_bar_graph_for_months(get_date_of_max_parking_lots(dataset2018, dataset2018_parkinglots), dataset2018)

# %%
create_bar_graph_for_months(get_date_of_max_parking_lots(dataset_ws, dataset_ws_parkinglots), dataset_ws)

# %%
create_bar_graph_for_months(get_date_of_max_parking_lots(dataset2019, dataset2019_parkinglots), dataset2019)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-38725773c7bc> in <module>
# ----> 1 create_bar_graph_for_months(get_date_of_max_parking_lots(dataset2019, dataset2019_parkinglots), dataset2019)
#
# <ipython-input-54-d8d6e38029c0> in create_bar_graph_for_months(df, full_dataset, ocup_limit)
#      33     d3.rename({'fecha': 'mes'},  axis=1, inplace=True)
#      34     d3 = d3[['mes', 'ocupacion']]
# ---> 35     d3 = d3.groupby(by=['mes']).count().reset_index()
#      36     d3.rename({'ocupacion': 'operaciones totales'}, axis=1, inplace=True)
#      37
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     650                 in_axis=in_axis,
#     651             )
# --> 652             if not isinstance(gpr, Grouping)
#     653             else gpr
#     654         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     345                 if getattr(self.grouper, "ndim", 1) != 1:
#     346                     t = self.name or str(type(self.grouper))
# --> 347                     raise ValueError("Grouper for '{}' not 1-dimensional".format(t))
#     348                 self.grouper = self.index.map(self.grouper)
#     349                 if not (
#
# ValueError: Grouper for 'mes' not 1-dimensional

# %% [markdown]
# ## Cantidad de movimientos por calle

# %%
def traffic_density(df, by_week=False):
    d = df.copy()
    
    if not by_week:
        d = d[['direccion','ocupacion']].groupby(by=['direccion']).count().reset_index()
    else:
        #display(d)
        d = d[['dia de la semana','ocupacion']].groupby(by=['dia de la semana']).count().reset_index()
    
    d = d.rename({'ocupacion': 'operaciones totales'}, axis=1)
    d = d.sort_values(by='operaciones totales', ascending=False)
    return d.reset_index(drop=True)

# %%
dataset2018_traffic_density = traffic_density(dataset2018)
dataset_ws_traffic_density = traffic_density(dataset_ws)
dataset2019_traffic_density = traffic_density(dataset2019)

# %%
merge_values(dataset2018_traffic_density, dataset_ws_traffic_density, dataset2019_traffic_density, not_on=['operaciones totales'], on='direccion', names=['2018_', 'ws_', '2019_'])

# %% [markdown]
# ## Cantidad de movimientos por dia de semana

# %%
df1 = traffic_density(dataset2018, by_week=True)
df2 = traffic_density(dataset_ws, by_week=True)
df3 = traffic_density(dataset2019, by_week=True)

#To plot graphs...
ax = plt.subplot(111)
ax.bar(df1['dia de la semana']-0.2, df1['operaciones totales'], width=0.2, color='green')
ax.bar(df2['dia de la semana'], df2['operaciones totales'], width=0.2, color='blue')
ax.bar(df3['dia de la semana']+0.2, df3['operaciones totales'] / 3, width=0.2, color='orange')

plt.xlabel("Dia de la semana")
plt.ylabel("Movimientos")
plt.title("")
plt.legend(['Dataset 2018', 'Dataset web scraping', 'Dataset 2019 (1/3)'])

plt.grid(axis='y')

ax.set_xticklabels(['abc', 'Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo'])

plt.show()

# %% [markdown]
# ## Cantidad de movimientos por hora

# %%
def traffic_density_per_hour(df):
    '''
    Obtain the total operations per hour
    
    Parameters:
        df: (DataFrame) a DataFrame containing all the data or only for
        one day, e.g. only with the monday data.
        
    Returns:
        in_out_per_hour: (DataFrame) df that contains the inputs, the outputs 
        and the sub: operaciones totales.
    '''
    
    d = df.copy()
    d = d[['id_cuadra', 'direccion', 'tiempo','operacion']]
    
    d['tiempo'] = d['tiempo'].apply(lambda x: x.hour)

    #Obtain 2 df, one with the count of the inputs and the other with the count of the outputs
    in_per_hour = d.loc[d['operacion'] == 1, ['tiempo', 'operacion']].groupby(by=['tiempo']).count().reset_index()
    out_per_hour = d.loc[d['operacion'] == 0, ['tiempo', 'operacion']].groupby(by=['tiempo']).count().reset_index()
    in_per_hour.rename(columns={'operacion': 'entradas'}, inplace=True)
    out_per_hour.rename(columns={'operacion': 'salidas'}, inplace=True)

    #Merge both in and out per hour to get the diff
    in_out_per_hour = in_per_hour.merge(out_per_hour, how='outer', on=['tiempo'])
    in_out_per_hour.fillna(0, axis=1, inplace=True)

    in_out_per_hour['operaciones totales'] = in_out_per_hour['entradas'] + in_out_per_hour['salidas']
    in_out_per_hour.rename(columns={'tiempo': 'hora'}, inplace=True)
    
    return in_out_per_hour[['hora','operaciones totales']].sort_values(by='operaciones totales').reset_index(drop=True)

# %%
df1 = traffic_density_per_hour(dataset2018).sort_values(by='hora')
df2 = traffic_density_per_hour(dataset_ws).sort_values(by='hora')
df3 = traffic_density_per_hour(dataset2019).sort_values(by='hora')

def plot_traffic_density_per_hour(df1, df2, df3):

    #To plot graphs...
    ax = plt.subplot(111)
    ax.plot(df1['hora'], df1['operaciones totales'], color='green')
    ax.plot(df2['hora'], df2['operaciones totales'], color='blue')
    ax.plot(df3['hora'], df3['operaciones totales'], color='orange')

    plt.xlabel("Dia de la semana")
    plt.ylabel("Movimientos")
    plt.title("")
    plt.legend(['Dataset 2018', 'Dataset web scraping', 'Dataset 2019'])

    plt.grid()

    #ax.set_xticklabels(['abc', 'Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo'])

    plt.show()

plot_traffic_density_per_hour(df1, df2, df3)

# %% [markdown]
# # Eleccion de calle y hora

# %%
street = dataset2019_traffic_density['direccion'].iloc[0]
hour = 10

print('Cuadra: ', street)
print('Hora:   ', hour)

# %% [markdown]
# ## Grafica de promedio de estacionamiento por mes

# %%
dataset2019['mes'] = dataset2019['fecha'].apply(lambda x: x.month)
dataset2019['hora'] = dataset2019['tiempo'].apply(lambda x: x.hour)

# %%
d = dataset2019.copy()

#d = d.loc[d['direccion'] == 'Sarmiento 755']

d = d[['mes', 'hora', 'ocupacion']]


d = d.groupby(by=['mes', 'hora']).mean().reset_index(drop=False)

# %%
for i in range(1, 12+1):
    to_plot = d.loc[d['mes'] == i]
    plt.plot(to_plot['hora'], to_plot['ocupacion'])
plt.grid()
plt.rcParams['figure.figsize'] = (15,8)
plt.xlabel('Hora')
plt.ylabel('Ocupacion')
plt.legend(['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'])
plt.show()

# %% [markdown]
# ## Grafica de promedio de estacionamiento por dia de semana

# %%
def plot_mean_parked_cars_weekday(df, weekday=False, color=['black','blue','yellow','green','red','brown','orange']):
    '''
        Plot a line graph for the mean parked cars along a street.
        
        Parameters:
            data: (DataFrame) a DataFrame containing all the data.
            street: (int) the street to chose the data.
    '''
    
    d = df.copy()
    week = ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo']

    d['tiempo'] = d['tiempo'].apply(lambda x: x.hour)
               
    def plot_values(d, color=['black','grey'], weekday=False):
    
        nonlocal i, week

        mean = d[['tiempo', 'ocupacion']].groupby(by='tiempo').mean().reset_index()
        mean.rename(columns={'ocupacion': 'mean_ocupacion'}, inplace=True)

        plt.plot(mean['tiempo'], mean['mean_ocupacion'], linewidth=2, color=color[0])
        
        patch = mpatches.Patch(color=color[0], label=week[i])
        return patch
    

    patches = []
    if weekday:
        for i in range(7):
            patches.append(plot_values(d.loc[d['dia de la semana']==i], color=[color[i], 'white'], weekday=weekday))
    else:
        plot_values(d)
        
    #Modify the plot size
    plt.rcParams['figure.figsize'] = (15,8)

    #plt.ylim([0,std_1.max()+2])

    #Set the label titles
    plt.xlabel('Hora')
    plt.ylabel('Autos estacionados')
    title = 'Autos estacionados en promedio.'
    
    plt.legend(handles=[patches[0], patches[1], patches[2], patches[3], patches[4], patches[5], patches[6]])

    plt.title(title)
    plt.grid()
    plt.show()

# %%
plot_mean_parked_cars_weekday(dataset2018, weekday=True)

# %%
plot_mean_parked_cars_weekday(dataset_ws, weekday=True)

# %%
plot_mean_parked_cars_weekday(dataset2019, weekday=True)

# %%
def get_std_per_weekday(df):
    d = df.copy()
    d['tiempo'] = d['tiempo'].apply(lambda x: x.hour)
    d['fecha'] = d['fecha'].apply(lambda x: x.weekday())
    week = ['Lun', 'Mar', 'Mie', 'Jue', 'Vie', 'Sab', 'Dom']
    std = []
    for i in range(7):
        std.append(d.loc[d.fecha == i, ['tiempo', 'ocupacion']].groupby(by=['tiempo']).std().reset_index().rename({'ocupacion': 'ocupacion_{}'.format(week[i])}, axis=1))

    out = std[0]
    for i in range(1, 7):
        out = out.merge(std[i], on='tiempo')
    out = out.loc[(out.tiempo > 8) & (out.tiempo < 21)]
    return out


dataset2018_std_per_week = get_std_per_weekday(dataset2018)
dataset_ws_std_per_week = get_std_per_weekday(dataset_ws)
dataset2019_std_per_week = get_std_per_weekday(dataset2019)

# %%
dataset2018_std_per_week

# %%
dataset_ws_std_per_week

# %%
dataset2019_std_per_week

# %% [markdown]
# ## Grafica de promedio de estacionamiento a lo largo del dia

# %%
# Se eliminan los sabados y los domingos ya que generan ruido en los datos normales. Esto sucede ya que
# el estacionamiento los sabados funciona hasta el mediodia y el domingo no funciona.

df1 = dataset2018.loc[dataset2018['dia de la semana'] < 5]
df2 = dataset_ws.loc[dataset_ws['dia de la semana'] < 5]
df3 = dataset2019.loc[dataset2019['dia de la semana'] < 5]

# %%
def plot_mean_parked_cars(df1, df2, df3):
    '''
        Plot a line graph for the mean parked cars along a street.
        
        Parameters:
            data: (DataFrame) a DataFrame containing all the data.
            street: (int) the street to chose the data.
    '''
    
    d1 = df1.copy()
    d2 = df2.copy()
    d3 = df3.copy()
    
    d1['tiempo'] = d1['tiempo'].apply(lambda x: x.hour)
    d2['tiempo'] = d2['tiempo'].apply(lambda x: x.hour)
    d3['tiempo'] = d3['tiempo'].apply(lambda x: x.hour)
            
    mean1 = d1[['tiempo', 'ocupacion']].groupby(by='tiempo').mean().reset_index()
    mean2 = d2[['tiempo', 'ocupacion']].groupby(by='tiempo').mean().reset_index()
    mean3 = d3[['tiempo', 'ocupacion']].groupby(by='tiempo').mean().reset_index()

    mean1.rename(columns={'ocupacion': 'mean_ocupacion'}, inplace=True)
    mean2.rename(columns={'ocupacion': 'mean_ocupacion'}, inplace=True)
    mean3.rename(columns={'ocupacion': 'mean_ocupacion'}, inplace=True)
               
    #Modify the plot size
    plt.rcParams['figure.figsize'] = (15,8)
    
    #Set the label titles
    plt.xlabel('Hora')
    plt.ylabel('Autos estacionados')
    title = 'Autos estacionados en promedio a lo largo de un dia'
    
    plt.title(title)

    #Set the plot data for each graph (ax1,ax2,ax3)
    ax = plt.subplot(111)
    ax.plot(mean1['tiempo'], mean1['mean_ocupacion'], linewidth=3, color='green')
    ax.plot(mean2['tiempo'], mean2['mean_ocupacion'], linewidth=3, color='blue')
    ax.plot(mean3['tiempo'], mean3['mean_ocupacion'], linewidth=3, color='orange')
    
    plt.legend(['Dataset 2018', 'Dataset web scraping', 'Dataset 2019'])
    plt.grid()
    plt.show()
    
plot_mean_parked_cars(df1, df2, df3)

# %% [markdown]
# ## In outs por hora

# %%
def inputs_outputs_per_hour(df, street=None):
    '''
    Obtain the inputs and outputs (and the sub of both) per street.
    
    Parameters:
        df: (DataFrame) a DataFrame containing all the data or only for
        one day, e.g. only with the monday data.
        
    Returns:
        in_out_per_hour: (DataFrame) df that contains the inputs, the outputs 
        and the sub: entradas-salidas.
    '''
    
    d = df.copy()
    d = d[['id_cuadra', 'direccion', 'tiempo','operacion']]
    
    if street is not None:
        d = d.loc[d.direccion == street]
    
    d['tiempo'] = d['tiempo'].apply(lambda x: x.hour)

    #Obtain 2 df, one with the count of the inputs and the other with the count of the outputs
    in_per_hour = d.loc[d['operacion'] == 1, ['tiempo', 'operacion']].groupby(by=['tiempo']).count().reset_index()
    out_per_hour = d.loc[d['operacion'] == 0, ['tiempo', 'operacion']].groupby(by=['tiempo']).count().reset_index()
    in_per_hour.rename(columns={'operacion': 'entradas'}, inplace=True)
    out_per_hour.rename(columns={'operacion': 'salidas'}, inplace=True)

    #Merge both in and out per hour to get the diff
    in_out_per_hour = in_per_hour.merge(out_per_hour, how='outer', on=['tiempo'])
    in_out_per_hour.fillna(0, axis=1, inplace=True)

    in_out_per_hour['entradas - salidas'] = in_out_per_hour['entradas'] - in_out_per_hour['salidas']
    in_out_per_hour.rename(columns={'tiempo': 'hora'}, inplace=True)
    
    return in_out_per_hour[['hora','entradas - salidas']].sort_values(by='entradas - salidas').reset_index(drop=True)

# %%
df1 = inputs_outputs_per_hour(dataset2018)
df2 = inputs_outputs_per_hour(dataset_ws)
df3 = inputs_outputs_per_hour(dataset2019)

display(merge_values(df1, df2, df3, not_on=['entradas - salidas'], on=['hora'])[0:])

# %%
df1 = inputs_outputs_per_hour(dataset2018).sort_values(by='hora')
df2 = inputs_outputs_per_hour(dataset_ws).sort_values(by='hora')
df3 = inputs_outputs_per_hour(dataset2019).sort_values(by='hora')

def plot_in_outs_per_hour(df1, df2, df3):
    ax = plt.subplot(111)
    ax.plot(df1['hora'], df1['entradas - salidas'], color='green')
    ax.plot(df2['hora'], df2['entradas - salidas'], color='blue')
    ax.plot(df3['hora'], df3['entradas - salidas'], color='orange')

    plt.xlabel("Hora")
    plt.ylabel("Salidas                                                             Entradas")
    plt.title("")
    plt.legend(['Dataset 2018', 'Dataset web scraping', 'Dataset 2019'])

    plt.grid()
    plt.show()

plot_in_outs_per_hour(df1, df2, df3)

# %% [markdown]
# ## Heat map

# %%
def get_data_to_plot(data, hour):
    '''
    
    '''
    d = data.copy()
    d = d.loc[d.direccion != 'Oficina SUMO'].reset_index(drop=True)
    d = d.loc[d.direccion != 'Tribunal de Faltas'].reset_index(drop=True)
    d = d[['id_cuadra','tiempo', 'fecha', 'direccion', 'ocupacion', 'latitud', 'longitud']]
    d['tiempo'] = d['tiempo'].apply(lambda x: x.hour)
    d = d.loc[d['tiempo'] == hour]
    d = d.groupby(by=['id_cuadra', 'direccion']).mean().reset_index()
    return d
    
    
def get_color_to_plot(data, max_ocupation, colors=['green','yellow','orange','red'], by='Cantidad promedio de estacionados'):
    '''
    
    '''
    d = data.copy()
    max_ocup = max_ocupation.copy()
    d = d.loc[d.direccion != 'Oficina SUMO'].reset_index(drop=True)
    d = d.loc[d.direccion != 'Tribunal de Faltas'].reset_index(drop=True)
    max_ocup = max_ocup.loc[max_ocup.direccion != 'Oficina SUMO'].reset_index(drop=True)
    max_ocup = max_ocup.loc[max_ocup.direccion != 'Tribunal de Faltas'].reset_index(drop=True)
    
    #display(d)
    #display(max_ocup)
    grade_1 = d['ocupacion'] <= (max_ocup[by] * 1/4)
    grade_2 = (~grade_1) & (d['ocupacion'] <= (max_ocup[by] * 2/4))
    grade_3 = (~grade_1) & (~grade_2) & (d['ocupacion'] <= (max_ocup[by] * 3/4))
    grade_4 = (~grade_1) & (~grade_2) & (~grade_3)

    color_data = pd.DataFrame(index=d.index.values, columns=['color'])
    color_data[grade_1] = colors[0]
    color_data[grade_2] = colors[1]
    color_data[grade_3] = colors[2]
    color_data[grade_4] = colors[3]

    color_list = []
    for c in color_data.values:
        color_list.append(c[0])

    color_data = color_list
    
    return color_data

import matplotlib.patches as mpatches

def plot_scatter_map(data, colour, date=None):

    plt.scatter(data['latitud'], data['longitud'], c=colour, s=70)
    plt.title('Mapa de calor en la hora: {}'.format(hour))
    plt.axis('off')
    plt.rcParams['figure.figsize'] = (25,15)

    green_patch = mpatches.Patch(color='green', label='< 1/4 max')
    yellow_patch = mpatches.Patch(color='yellow', label='1/4 max < x < 1/2 max')
    orange_patch = mpatches.Patch(color='orange', label='1/4 max < x < 3/4 max')
    red_patch = mpatches.Patch(color='red', label='> 3/4 max')
    
    plt.legend(handles=[green_patch, yellow_patch, orange_patch, red_patch])
    plt.show()

# %%
#Con cantidad maxima de estacionados

dataset2019_without_sat_sun = dataset2019.loc[dataset2019['dia de la semana'] < 5]

plot_data = get_data_to_plot(dataset2019_without_sat_sun, 10)

dataset2019_parkinglots_without_sat_sun = get_parking_lots(dataset2019_without_sat_sun).sort_values(by='Cantidad maxima de estacionados', ascending=False).reset_index(drop=True)
plot_color = get_color_to_plot(plot_data, dataset2019_parkinglots_without_sat_sun, by='Cantidad maxima de estacionados')

plot_data['latitud'] = plot_data['latitud'] * -1

#plot_data
plot_scatter_map(plot_data, plot_color)

# %%
#Con promedio de maximo de estacionados

dataset2019_without_sat_sun = dataset2019.loc[dataset2019['dia de la semana'] < 5]

plot_data = get_data_to_plot(dataset2019_without_sat_sun, 10)

dataset2019_parkinglots_without_sat_sun = get_parking_lots(dataset2019_without_sat_sun).sort_values(by='Cantidad maxima de estacionados', ascending=False).reset_index(drop=True)
plot_color = get_color_to_plot(plot_data, dataset2019_parkinglots_without_sat_sun)

plot_data['latitud'] = plot_data['latitud'] * -1

#plot_data
plot_scatter_map(plot_data, plot_color)

# %% [markdown]
# ## Balance de clases para un clasificador

# %%
def print_balanced_classes(df):
    d = df.copy()
    d = d.groupby(by='operacion').count()[['id_cuadra']]
    d.rename(columns={'id_cuadra': 'Cantidad datos'}, inplace=True)
    if pow(pow(d.iloc[0].values - d.iloc[1].values, 2), 0.5) > (len(df) * 0.4):
        print('Clases no balanceadas.')
    else:
        print('Clases balanceadas.')
    display(d)
    
print_balanced_classes(dataset2018)
print_balanced_classes(dataset_ws)
print_balanced_classes(dataset2019)

# %%
import gc
gc.collect()
