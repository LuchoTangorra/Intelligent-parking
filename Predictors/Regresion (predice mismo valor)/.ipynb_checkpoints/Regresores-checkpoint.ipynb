# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime 
from IPython.display import display, HTML, clear_output
import gc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import BayesianRidge
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from math import sqrt
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Embedding, Concatenate, Flatten, LSTM, Conv1D, MaxPooling1D
from tensorflow.keras.models import Model

# %%
dhh_max = r'C:\Users\ing_l\Tesis grado\Data\Predictors data\Dataset2019_half_hour_max.csv'
dhour_max = r'C:\Users\ing_l\Tesis grado\Data\Predictors data\Dataset2019_hour_max.csv'
dhh_mean = r'C:\Users\ing_l\Tesis grado\Data\Predictors data\Dataset2019_half_hour_mean.csv'
dhour_mean = r'C:\Users\ing_l\Tesis grado\Data\Predictors data\Dataset2019_hour_mean.csv'

# %%
data = pd.read_csv(dhh_max)
tiempo = 'media hora'

data.drop('Unnamed: 0', axis=1, inplace=True)
data['fecha'] = data['fecha'].apply(lambda x: pd.to_datetime(x).date())
d = data.copy()
data
# Out:
#         dia de la semana       fecha  id_cuadra  media hora  mes  ocupacion  \
# 0                      2  2019-01-02          0       36000    1          2
# 1                      2  2019-01-02          0       37800    1          1
# 2                      2  2019-01-02          0       39600    1          5
# 3                      2  2019-01-02          0       41400    1          4
# 4                      2  2019-01-02          0       43200    1          2
# ...                  ...         ...        ...         ...  ...        ...
# 476452                 1  2019-09-17        190       39600    9          1
# 476453                 1  2019-09-17        190       41400    9          1
# 476454                 1  2019-11-12        190       36000   11          0
# 476455                 1  2019-11-19        190       34200   11          1
# 476456                 1  2019-11-19        190       41400   11          1
#
#         ocupacion anterior  targets
# 0                        3        1
# 1                        2        5
# 2                        1        4
# 3                        5        2
# 4                        4        3
# ...                    ...      ...
# 476452                   1        1
# 476453                   1        1
# 476454                   0        1
# 476455                   1        1
# 476456                   1        1
#
# [476457 rows x 8 columns]

# %% [markdown]
# ### Se eliminan los fines de semana (para tener los datos lo mas parejo posible)

# %%
# Eliminamos los fines de semana
data = data.loc[data['dia de la semana'] < 5]

# %% [markdown]
# ###  Se eliminan los outliers

# %%
data_no_outliers = pd.DataFrame(columns=data.columns)
for s in data['id_cuadra'].drop_duplicates().sort_values():
    clear_output()
    print('Street:', s)
    
    data_street = data.loc[data['id_cuadra'] == s]
    outlier = data_street.boxplot(column='targets', return_type='dict')['whiskers'][1].get_ydata()[1]
    
    data_no_outliers = data_no_outliers.append(data_street.loc[data_street['targets'] <= outlier])
# Out:
# Street: 190

# %% [markdown]
# ### Normalizamos la feature "media hora" que posee valores demasiado altos
#
# #### Para esto se hace x / (valor de un hora en segundos) = hora

# %%
if 'media hora' in tiempo:
    data_no_outliers[tiempo] = data_no_outliers[tiempo] / (1800 * 2)

# %%
data_no_outliers
# Out:
#        dia de la semana       fecha id_cuadra media hora mes ocupacion  \
# 0                     2  2019-01-02         0         10   1         2
# 1                     2  2019-01-02         0       10.5   1         1
# 2                     2  2019-01-02         0         11   1         5
# 3                     2  2019-01-02         0       11.5   1         4
# 4                     2  2019-01-02         0         12   1         2
# ...                 ...         ...       ...        ...  ..       ...
# 476452                1  2019-09-17       190         11   9         1
# 476453                1  2019-09-17       190       11.5   9         1
# 476454                1  2019-11-12       190         10  11         0
# 476455                1  2019-11-19       190        9.5  11         1
# 476456                1  2019-11-19       190       11.5  11         1
#
#        ocupacion anterior targets
# 0                       3       1
# 1                       2       5
# 2                       1       4
# 3                       5       2
# 4                       4       3
# ...                   ...     ...
# 476452                  1       1
# 476453                  1       1
# 476454                  0       1
# 476455                  1       1
# 476456                  1       1
#
# [437785 rows x 8 columns]

# %% [markdown]
# ### Se eligen los features de input

# %%
input_features_cat = ['id_cuadra', 'mes', 'dia de la semana', tiempo, 'ocupacion', 'ocupacion anterior']
input_features_no_cat = ['id_cuadra', tiempo, 'ocupacion', 'ocupacion anterior']
input_features_no_cat_no_street = [tiempo, 'ocupacion', 'ocupacion anterior']

# %% [markdown]
# ### Se eligen los datos de validacion

# %%
cuadra1 = 12
fecha1 = 1

fecha1 = data_no_outliers['fecha'].drop_duplicates().iloc[fecha1]

filt = (data_no_outliers['id_cuadra'] == cuadra1) & (data_no_outliers['fecha'] == fecha1) 
x_val1 = data_no_outliers.loc[filt, input_features_cat]
y_val1 = data_no_outliers.loc[filt, 'targets']

data_no_outliers = data_no_outliers.loc[~filt]

# %%
x_val1
# Out:
#       id_cuadra mes dia de la semana media hora ocupacion ocupacion anterior
# 69693        12   1                3         10         7                  3
# 69694        12   1                3       10.5        11                  7
# 69695        12   1                3         11        14                 11
# 69696        12   1                3       11.5        16                 14
# 69697        12   1                3         12        17                 16
# 69698        12   1                3       12.5        10                 17
# 69699        12   1                3         13         8                 10
# 69700        12   1                3       13.5         9                  8
# 69701        12   1                3       14.5         9                  9
# 69702        12   1                3         15         7                  9
# 69703        12   1                3       15.5         6                  7
# 69704        12   1                3       16.5         8                  6
# 69705        12   1                3         17         7                  8
# 69706        12   1                3       17.5         6                  7
# 69707        12   1                3         18         7                  6
# 69708        12   1                3       18.5         5                  7
# 69709        12   1                3         19         7                  5
# 69710        12   1                3       19.5         6                  7

# %%
cuadra2 = 32
fecha2 = 16

fecha2 = data_no_outliers['fecha'].drop_duplicates().iloc[fecha2]

filt = (data_no_outliers['id_cuadra'] == cuadra2) & (data_no_outliers['fecha'] == fecha2) 
x_val2 = data_no_outliers.loc[filt, input_features_cat]
y_val2 = data_no_outliers.loc[filt, 'targets']

data_no_outliers = data_no_outliers.loc[~filt]

# %%
x_val2
# Out:
#        id_cuadra mes dia de la semana media hora ocupacion ocupacion anterior
# 181813        32   1                4        9.5         4                  3
# 181814        32   1                4         10         7                  4
# 181815        32   1                4       10.5        10                  7
# 181816        32   1                4         11        10                 10
# 181817        32   1                4       11.5         8                 10
# 181818        32   1                4         12         9                  8
# 181819        32   1                4       12.5         8                  9
# 181820        32   1                4         13         5                  8
# 181821        32   1                4       13.5         6                  5
# 181822        32   1                4         14         9                  6
# 181823        32   1                4       14.5        12                  9
# 181824        32   1                4         15        11                 12
# 181825        32   1                4       15.5        13                 11
# 181826        32   1                4         16        10                 13
# 181827        32   1                4       16.5        12                 10
# 181828        32   1                4         17        14                 12
# 181829        32   1                4       17.5        15                 14
# 181830        32   1                4         18        16                 15
# 181831        32   1                4       18.5        14                 16
# 181832        32   1                4         19        12                 14
# 181833        32   1                4       19.5        14                 12
# 181834        32   1                4         20         8                 14
# 181835        32   1                4       20.5         6                  8

# %% [markdown]
# ### Se divide en test y train y se eligen los parametros con mayor correlacion

# %%
#Con outliers
#data_to_split = data
#Sin outliers

data_to_split = data_no_outliers

#x_train, x_test, y_train, y_test = train_test_split(data_to_split[input_features], data_to_split['targets'], test_size=0.2, shuffle=True, stratify=data_to_split['targets'])

#Sin outliers
x_train, x_test, y_train, y_test = train_test_split(data_to_split[input_features_cat], data_to_split['targets'], test_size=0.1, shuffle=True)

# %% [markdown]
# ### Funcion para plotear los datos predichos

# %%
def plot_predicted_data(predictions, x_val=None, y_val=None):
    try:
        try:
            predictions = [round(x[0]) for x in predictions]
        except:
            predictions = [round(x) for x in predictions]
    except:
        predictions = predictions
    targets_time = x_val[tiempo] + 1 # 1 = normalized half hour
    
    plt.plot(targets_time, y_val, color='blue')
    plt.scatter(targets_time, y_val, color='blue')
    
    plt.scatter(targets_time, predictions, color='orange')
    plt.plot(targets_time, predictions, color='orange')
    plt.legend(['Y','Yhat'])  
    
    plt.grid()
    plt.xlabel('Tiempo (h)')
    plt.ylabel('Ocupacion')

    clear_output()
    plt.show()
    #out = x_val.copy()
    #out['targets'] = y_val
    #out['predicted targets'] = predictions
    #display(out)

# %% [markdown]
# # Baseline ocupacion input == output

# %%
r2_misma_pred = r2_score(y_test, x_test['ocupacion'])
print("Score (R2):", r2_misma_pred)
# Out:
# Score (R2): 0.8075493372273055

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # Predictores!

# %% [markdown]
# # Bayesian Ridge

# %% [markdown]
# ### full dataset

# %%
model = BayesianRidge()
model.fit(x_train[input_features_no_cat_no_street], y_train)
# Out:
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False)

# %%
print('Score total (R^2):                    ', model.score(x_test[input_features_no_cat_no_street], y_test))
print('Score total (RMSE):                   ', sqrt(mean_squared_error(y_test, model.predict(x_test[input_features_no_cat_no_street]))))
# Out:
# Score total (R^2):                     0.8278783668944779
# Score total (RMSE):                    2.103313525095484

# %%
plot_predicted_data(model.predict(x_val1[input_features_no_cat_no_street]), x_val1[input_features_no_cat_no_street], y_val1)#, to_left=True)

# %%
plt.scatter(y_test, model.predict(x_test[input_features_no_cat_no_street]), color='orange')
plt.plot(range(0, int(y_test.max())+1), range(0, int(y_test.max())+1), color='black')
plt.grid()
plt.xlabel('prueba')
plt.ylabel('predichos')
plt.show()

# %% [markdown]
# ### Por cuadra

# %%
scores = []
models = []
for s in data['id_cuadra'].drop_duplicates().sort_values():
    clear_output()
    print('Street:', s)

    model = BayesianRidge()
    
    x = x_train[input_features_no_cat].loc[x_train['id_cuadra'] == s]
    train_indexes = x.index
    model.fit(x, y_train.loc[train_indexes])
    
    models.append(model)
    
    x_t = x_test[input_features_no_cat].loc[x_test['id_cuadra'] == s]
    if len(x_t) > 0:
        scores.append(model.score(x_t, y_test.loc[x_t.index]))
# Out:
# Street: 190

# %%
model_ix = data['id_cuadra'].drop_duplicates().sort_values().reset_index(drop=True)
model_ix = model_ix.loc[model_ix == cuadra1].index.astype(int)
model_ix = model_ix[0]

plot_predicted_data(models[model_ix].predict(x_val1[input_features_no_cat]), x_val1, y_val1)

# %%
#Para obtener el RMSE
RMSE = 0
for s in data['id_cuadra'].drop_duplicates().sort_values():
    
    x = x_test[input_features_no_cat].loc[x_test['id_cuadra'] == s]
    if len(x) > 0:
        RMSE += sqrt(mean_squared_error(y_test.loc[x.index], model.predict(x)))
RMSE = RMSE / len(data['id_cuadra'].drop_duplicates())

# %%
total_score = sum(scores) / len(scores)
print('Score total (R^2):  ', total_score)
print('Score total (RMSE): ', RMSE)

height = [x for x in range(len(scores))]
plt.bar(height, scores)
plt.rcParams['figure.figsize'] = (15,8)

plt.plot([0,len(scores)], [r2_misma_pred,r2_misma_pred], color='black')
plt.yticks([x for x in np.arange(0, 1, 0.1)])
plt.xlabel('id_cuadra')
plt.ylabel('score')
plt.grid(axis='y')

plt.show()
# Out:
# Score total (R^2):   0.6262100762372843
# Score total (RMSE):  5.888814568430738

# %%
#Podemos mostrar el grafico para las cuadras...
id_cuadra = 0
max_y = 0
for s in range(len(x_test['id_cuadra'].drop_duplicates())):
    clear_output()
    print('Street:', s)
    x = x_test[input_features_no_cat].loc[x_test['id_cuadra'] == s]
    
    if len(x) > 5:
        indexes = x.index
        plt.scatter(y_test.loc[indexes], models[s].predict(x), color='orange')
        if y_test.loc[indexes].max() > max_y:
            max_y = y_test.loc[indexes].max()

clear_output()
plt.plot(range(0, int(max_y)), range(0, int(max_y)), color='black')
plt.grid()
plt.show()

# %%
gc.collect()
# Out:
# 85506

# %% [markdown]
# # Arboles de regresion

# %% [markdown]
# ### Full dataset

# %%
max_depth = 20

best_model = None
best_score = 0

for i in range(1, max_depth+1):
    clear_output()
    print('Profundidad:', i)
    model = tree.DecisionTreeRegressor(max_depth=i)
    model.fit(x_train[input_features_no_cat_no_street], y_train)
    score = model.score(x_test[input_features_no_cat_no_street], y_test)
    
    if score > best_score:
        best_score = score
        best_model = model
        
clear_output()
print('Profundidad del mejor score:', best_model.get_depth())
print('Cantidad de hojas del mejor score:', best_model.get_n_leaves())
print('')
print('Mejor score:', best_score)
print('RMSE:', sqrt(mean_squared_error(y_test, model.predict(x_test[input_features_no_cat_no_street]))))
# Out:
# Profundidad del mejor score: 12
# Cantidad de hojas del mejor score: 2147
#
# Mejor score: 0.8586340396219792
# RMSE: 1.9242963257930696

# %%
plot_predicted_data(best_model.predict(x_val1[input_features_no_cat_no_street]), x_val1, y_val1)

# %%
plt.scatter(y_test, model.predict(x_test[input_features_no_cat_no_street]), color='orange')
plt.plot(range(0, int(y_test.max())+1), range(0, int(y_test.max())+1), color='black')
plt.grid()
plt.xlabel('prueba')
plt.ylabel('predichos')
plt.show()

# %% [markdown]
# ### Por cuadra

# %%
max_depth = 20

scores = []
models = []

for s in data['id_cuadra'].drop_duplicates().sort_values():
    clear_output()
    print('Street:', s)

    best_model = None
    best_score = 0
    
    for i in range(1, max_depth+1):
        print('Profundidad:', i)
        
        model = tree.DecisionTreeRegressor(max_depth=i)

        x = x_train[input_features_no_cat].loc[x_train['id_cuadra'] == s]
        train_indexes = x.index
        model.fit(x, y_train.loc[train_indexes])
        
        xt = x_test[input_features_no_cat].loc[x_test['id_cuadra'] == s]
        test_indexes = xt.index
        if len(xt) > 0:
            score = model.score(xt, y_test.loc[test_indexes])
        else:
            score = 0
        if score > best_score:
            best_score = score
            best_model = model
        
    models.append(best_model)

    scores.append(best_score)
    
clear_output()

# %%
model_ix = data['id_cuadra'].drop_duplicates().sort_values().reset_index(drop=True)
model_ix = model_ix.loc[model_ix == cuadra1].index.astype(int)
model_ix = model_ix[0]

plot_predicted_data(models[model_ix].predict(x_val1[input_features_no_cat]), x_val1, y_val1)

# %%
#Para obtener el RMSE
RMSE = 0
index = 0
for s in data['id_cuadra'].drop_duplicates():
    
    x = x_test[input_features_no_cat].loc[x_test['id_cuadra'] == s]
    if len(x) > 0:
        RMSE += sqrt(mean_squared_error(y_test.loc[x.index], model.predict(x)))
    
    index+=1
RMSE = RMSE / len(data['id_cuadra'].drop_duplicates())

# %%
total_score = sum(scores) / len(scores)
print('Score total (R^2):  ', total_score)
print('Score total (RMSE): ', RMSE)

height = [x for x in range(len(scores))]
plt.bar(height, scores)
plt.rcParams['figure.figsize'] = (15,8)

plt.plot([0,len(scores)], [r2_misma_pred,r2_misma_pred], color='black')
plt.yticks([x for x in np.arange(0, 1, 0.1)])
plt.xlabel('id_cuadra')
plt.ylabel('score')
plt.grid(axis='y')

plt.show()
# Out:
# Score total (R^2):   0.6610471171476087
# Score total (RMSE):  5.888814568430738

# %%
#Podemos mostrar el grafico para las cuadras...
id_cuadra = 0
max_y = 0
for s in range(len(x_test['id_cuadra'].drop_duplicates())):
    clear_output()
    print('Street:', s)
    x = x_test[input_features_no_cat].loc[x_test['id_cuadra'] == s]
    
    if len(x) > 5:
        indexes = x.index
        if models[s] is not None:
            plt.scatter(y_test.loc[indexes], models[s].predict(x), color='orange')
            if y_test.loc[indexes].max() > max_y:
                max_y = y_test.loc[indexes].max()

clear_output()
plt.plot(range(0, int(max_y)), range(0, int(max_y)), color='black')
plt.grid()
plt.show()

# %% [markdown]
# # Random forest

# %%
max_depth = 20

best_model = None
best_score = 0

for i in range(1, max_depth+1):
    clear_output()
    print('Profundidad:', i)
    model = RandomForestRegressor(n_estimators=100, max_depth=i)
    model.fit(x_train[input_features_no_cat_no_street], y_train)
    score = model.score(x_test[input_features_no_cat_no_street], y_test)
    
    if score > best_score:
        best_score = score
        best_model = model
        
clear_output()
#print('Profundidad del mejor score:', best_model.get_depth())
#print('Cantidad de hojas del mejor score:', best_model.get_n_leaves())
#print('')
print('Mejor score:', best_score)
print('RMSE:', sqrt(mean_squared_error(y_test, model.predict(x_test[input_features_no_cat_no_street]))))
# Out:
# Mejor score: 0.8599452838854197
# RMSE: 1.912790211248965

# %%
s = 22
plot_predicted_data(best_model.predict(x_val1[input_features_no_cat_no_street]), x_val1, y_val1)

# %%
plt.scatter(y_test, model.predict(x_test[input_features_no_cat_no_street]), color='orange')
plt.plot(range(0, int(y_test.max())+1), range(0, int(y_test.max())+1), color='black')
plt.grid()
plt.xlabel('prueba')
plt.ylabel('predichos')
plt.show()

# %% [markdown]
# # Redes neuronales

# %% [markdown]
# ### Regresion lineal

# %%
i = Input(shape=(len(input_features_no_cat_no_street)), name='input')
o = Dense(1, activation='linear')(i)

model = Model(inputs=i, outputs=o)
model.summary()
model.compile(loss='MAE', optimizer='adam', metrics=['MSE'])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3)]               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 4
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
h = model.fit(x_train[input_features_no_cat_no_street], y_train, epochs=20, batch_size=64, validation_data=[x_test[input_features_no_cat_no_street],y_test])
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 393969 samples, validate on 43775 samples
# Epoch 1/20
# 393969/393969 [==============================] - 5s 14us/sample - loss: 2.1471 - MSE: 8.8972 - val_loss: 1.5948 - val_MSE: 4.5134 0s - loss: 2.1830 - MSE:
# Epoch 2/20
# 393969/393969 [==============================] - 6s 14us/sample - loss: 1.5882 - MSE: 4.4591 - val_loss: 1.5850 - val_MSE: 4.44814s - lo - ETA: 3s - loss: 1.5911 - MSE:  - ETA: 2s - loss: 1. - ETA: 1s - lo - ETA: 0s - loss: 1.5884 - MSE: 4 - ETA: 0s - loss: 1.5881 - MSE: 4.45
# Epoch 3/20
# 393969/393969 [==============================] - 6s 15us/sample - loss: 1.5848 - MSE: 4.4410 - val_loss: 1.5850 - val_MSE: 4.4485ss: 1.5851  - ETA: 1s - loss: 1.5859 - MSE: 4.438 - ETA: 1s - loss: 1.5860 - MSE: 4.441 - ETA: 1s - loss: 1.5857 - MSE: 4.439 - ETA: 1s - loss: 1.5852 - MSE: 4.437 - ETA: 0s - loss: 1.5852 - M - ETA: 0s - loss: 1.5842 - MSE: 4.43 - ETA: 0s - loss: 1.5846 - MSE: 4.43
# Epoch 4/20
# 393969/393969 [==============================] - 6s 16us/sample - loss: 1.5845 - MSE: 4.4379 - val_loss: 1.5845 - val_MSE: 4.4569- loss: 1.5838 - MSE: 4.446 - ETA: 4s - loss: 1.5807 - - ETA: 3s - loss: 1.5844 - MSE: 4.43 - ETA: 3s - loss - ETA: 2s - loss:
# Epoch 5/20
# 393969/393969 [==============================] - 7s 17us/sample - loss: 1.5842 - MSE: 4.4371 - val_loss: 1.5847 - val_MSE: 4.4395
# Epoch 6/20
# 393969/393969 [==============================] - 5s 14us/sample - loss: 1.5844 - MSE: 4.4372 - val_loss: 1.5858 - val_MSE: 4.46884s - loss: 1.6022 - MSE: 4. - ETA: 4s - loss: 1.5942 - MS - ETA: 3s - loss: 1.5873 - MSE: 4.443 - ETA: 3s - loss: 1.5869 -  - ETA: 2s - loss: 1.5859 - MSE - ETA: 2s - loss: 1.5865 - MSE:  - ETA: 0s - loss: 1.5850 - MSE: 4.44
# Epoch 7/20
# 393969/393969 [==============================] - 5s 13us/sample - loss: 1.5844 - MSE: 4.4382 - val_loss: 1.5838 - val_MSE: 4.4394840 - - ETA: 2s - loss - ETA: 1s - loss: 1.5837 - MSE: - ETA: 1s - loss: 1.5853 - MSE: 4.43 - ETA: 1s - loss: 1.5848 - MSE: 4.43 - ETA: 1s - loss: 1.5846 - MSE: 4 - ETA: 0s - loss: 1.5849 -
# Epoch 8/20
# 393969/393969 [==============================] - 5s 13us/sample - loss: 1.5844 - MSE: 4.4370 - val_loss: 1.5844 - val_MSE: 4.4559s - loss: 1.5892 - MSE: 4.444 - ETA: 4s - loss: 1.5882 - MSE: 4.432 - ETA: 4s - l - ETA: 2s - loss: 1.581 - ETA: 1s - loss: 1.5841  - ETA: 0s - loss: 1.5849 - MSE: 4. - ETA: 0s - loss: 1.5855 - MS
# Epoch 9/20
# 393969/393969 [==============================] - 5s 13us/sample - loss: 1.5843 - MSE: 4.4373 - val_loss: 1.5839 - val_MSE: 4.4435- ETA: 2s - loss: 1.5897 - MSE: 4.4 - ETA: 2s - loss: 1.5889 - MSE:  - ETA: 1s - loss: 1.5879 - MSE: 4 - ETA: 1s - lo
# Epoch 10/20
# 393969/393969 [==============================] - 5s 13us/sample - loss: 1.5844 - MSE: 4.4379 - val_loss: 1.5844 - val_MSE: 4.44425813 - MSE: 4 - ETA: 2s - loss: 1.5810 - M - ETA: 1s - loss: 1.5824 - ETA: 1s - loss: 1.5842 - MSE: 4 - ETA: 0s - loss: 1.5842 - MSE: 4.430 - ETA: 0s - loss: 1.5842
# Epoch 11/20
# 393969/393969 [==============================] - 6s 15us/sample - loss: 1.5843 - MSE: 4.4365 - val_loss: 1.5844 - val_MSE: 4.4522 - loss: 1.5863 - MSE - ETA: 3s - loss: 1.5846 - MSE:  - ETA: 3s - loss: 1.5893 - - ETA: 2s - loss: 1.5874  - ETA: 1s - loss: - ETA: 0s - loss: 1.5850 -
# Epoch 12/20
# 393969/393969 [==============================] - 6s 16us/sample - loss: 1.5843 - MSE: 4.4368 - val_loss: 1.5838 - val_MSE: 4.4488 6s - loss: 1.5854 - MSE: 4.44 - ETA: 5s - loss: 1.5840 - MSE: - ETA: 4s - loss: 1.5837 - MSE: 4.434 - ETA: 4s - loss: 1.5832 - MS - ETA: 3s - loss: 1.5844 - MSE:  - ETA: 3s - loss: 1.5832 - MSE: 4.4 - ETA: 2s - loss: 1.5840  - ETA: 1s - loss: 1.5844 - MSE: 4.44 - ETA: 1s - loss: 1.5839 - MSE: 4.437 - ETA: 1s - loss: - ETA: 0s - loss: 1.5844 - MSE:
# Epoch 13/20
# 393969/393969 [==============================] - 6s 15us/sample - loss: 1.5843 - MSE: 4.4376 - val_loss: 1.5852 - val_MSE: 4.4629s - los - ETA: 1s - loss: 1.5838 - MSE: 4.43 - ETA: 1s - loss: 1.5840 - MS - ETA: 1s - loss: 1.5
# Epoch 14/20
# 393969/393969 [==============================] - 6s 14us/sample - loss: 1.5844 - MSE: 4.4371 - val_loss: 1.5843 - val_MSE: 4.45204s - loss: 1.5842 - MSE: 4.439 - ETA: 4s - loss: 1.5857 - MSE: 4.44 - ETA: 3s -  - ETA: 2s - loss: 1.5822 - MSE: 4. - ETA: 2s - loss: 1 - ETA: 0s - loss: 1.5828 - MSE: 4.42 - ETA: 0s - loss: 1.5832 - MSE:  - ETA: 0s - loss: 1.5827 - MSE: 4.42 - ETA: 0s - loss: 1.5832 - MSE: 4.42 - ETA: 0s - loss: 1.5833 -
# Epoch 15/20
# 393969/393969 [==============================] - 7s 17us/sample - loss: 1.5843 - MSE: 4.4368 - val_loss: 1.5837 - val_MSE: 4.4481- loss: 1.5828 - MSE - ETA: 2s - loss: 1 -
# Epoch 16/20
# 393969/393969 [==============================] - 6s 16us/sample - loss: 1.5842 - MSE: 4.4369 - val_loss: 1.5841 - val_MSE: 4.4402: 1.5846 - MSE: 4.4 - ETA: 0s - loss: 1.5843 - MSE: 4.43
# Epoch 17/20
# 393969/393969 [==============================] - 5s 13us/sample - loss: 1.5845 - MSE: 4.4378 - val_loss: 1.5845 - val_MSE: 4.4575 0s - loss: 1.5848 - MSE:
# Epoch 18/20
# 393969/393969 [==============================] - 5s 13us/sample - loss: 1.5844 - MSE: 4.4377 - val_loss: 1.5845 - val_MSE: 4.4507 3s - loss: 1.5853 - MSE: 4. - ETA: 2s - loss: 1.5851 - MSE: 4.437 - ETA: 2s - loss: 1.5854 - MSE: 4.438 - ETA: 2s - loss: 1.58 - ETA: 1s -  - ETA: 0s - loss: 1.5848 - MSE: 4.4
# Epoch 19/20
# 393969/393969 [==============================] - 5s 14us/sample - loss: 1.5843 - MSE: 4.4372 - val_loss: 1.5845 - val_MSE: 4.4567
# Epoch 20/20
# 393969/393969 [==============================] - 5s 14us/sample - loss: 1.5844 - MSE: 4.4378 - val_loss: 1.5841 - val_MSE: 4.4442- MSE - ETA: 1s -

# %%
RMSE = sqrt(h.history['val_MSE'][len(h.history['val_MSE'])-1])
print("Score (R2):", r2_score(y_test, model.predict(x_test[input_features_no_cat_no_street])))
print('RMSE:', RMSE)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Score (R2): 0.8270899887421089
# RMSE: 2.1081253305995307

# %%
print('Input features:', input_features_no_cat_no_street)
print('Model weights:', model.layers[1].get_weights()[0])
# Out:
# Input features: ['media hora', 'ocupacion', 'ocupacion anterior']
# Model weights: [[-0.12376689]
#  [ 1.0473458 ]
#  [-0.13699614]]

# %%
plot_predicted_data(model.predict(x_val1[input_features_no_cat_no_street]), x_val1, y_val1)

# %%
plt.scatter(y_test, model.predict(x_test[input_features_no_cat_no_street]), color='orange')
plt.plot(range(0, int(y_test.max())+1), range(0, int(y_test.max())+1), color='black')
plt.grid()
plt.xlabel('prueba')
plt.ylabel('predichos')
plt.show()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %% [markdown]
# ### Red neuronal

# %%
i = Input(shape=(len(input_features_no_cat_no_street)), name='input')
d = Dense(64, activation='relu')(i)
d = Dropout(0.3)(d)
d = Dense(64, activation='relu')(d)
o = Dense(1, activation='linear')(d)

model = Model(inputs=i, outputs=o)
model.summary()
model.compile(loss='MAE', optimizer='adam', metrics=['MSE'])
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,481
# Trainable params: 4,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
h = model.fit(x_train[input_features_no_cat_no_street], y_train, epochs=20, batch_size=128, validation_data=[x_test[input_features_no_cat_no_street],y_test])
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 393969 samples, validate on 43775 samples
# Epoch 1/20
# 393969/393969 [==============================] - 4s 11us/sample - loss: 1.6768 - MSE: 5.0600 - val_loss: 1.9367 - val_MSE: 6.8640
# Epoch 2/20
# 393969/393969 [==============================] - 4s 11us/sample - loss: 1.5883 - MSE: 4.5192 - val_loss: 2.1180 - val_MSE: 8.2861 1.5989 - MSE: 4 - ETA: 2s - - ETA: 0s - loss: 1.5897 - MS
# Epoch 3/20
# 393969/393969 [==============================] - 4s 11us/sample - loss: 1.5706 - MSE: 4.4348 - val_loss: 2.0866 - val_MSE: 8.0989
# Epoch 4/20
# 393969/393969 [==============================] - 4s 10us/sample - loss: 1.5571 - MSE: 4.3663 - val_loss: 2.1216 - val_MSE: 8.3694
# Epoch 5/20
# 393969/393969 [==============================] - 4s 11us/sample - loss: 1.5425 - MSE: 4.2843 - val_loss: 2.0510 - val_MSE: 7.9338
# Epoch 6/20
# 393969/393969 [==============================] - 4s 11us/sample - loss: 1.5272 - MSE: 4.1932 - val_loss: 2.1220 - val_MSE: 8.43850s - loss: 1.5282 - MSE: - ETA: 0s - loss: 1.5275 - MSE: 4.195
# Epoch 7/20
# 393969/393969 [==============================] - 5s 14us/sample - loss: 1.5142 - MSE: 4.1253 - val_loss: 1.9991 - val_MSE: 7.4452
# Epoch 8/20
# 393969/393969 [==============================] - 4s 11us/sample - loss: 1.5050 - MSE: 4.0816 - val_loss: 1.9503 - val_MSE: 7.1120ss: 1.5047 - MSE: 4.07 - ETA: 0s - loss: 1.5054 - MSE:
# Epoch 9/20
# 393969/393969 [==============================] - 4s 11us/sample - loss: 1.4958 - MSE: 4.0293 - val_loss: 1.9186 - val_MSE: 6.9082
# Epoch 10/20
# 393969/393969 [==============================] - 6s 14us/sample - loss: 1.4908 - MSE: 3.9994 - val_loss: 1.8593 - val_MSE: 6.4382
# Epoch 11/20
# 393969/393969 [==============================] - 5s 12us/sample - loss: 1.4818 - MSE: 3.9519 - val_loss: 1.9670 - val_MSE: 7.2278
# Epoch 12/20
# 393969/393969 [==============================] - 5s 13us/sample - loss: 1.4770 - MSE: 3.9256 - val_loss: 1.9393 - val_MSE: 7.0696
# Epoch 13/20
# 393969/393969 [==============================] - 5s 13us/sample - loss: 1.4730 - MSE: 3.9055 - val_loss: 1.8658 - val_MSE: 6.52751s - loss
# Epoch 14/20
# 393969/393969 [==============================] - 4s 11us/sample - loss: 1.4733 - MSE: 3.9105 - val_loss: 1.9245 - val_MSE: 6.8522 - MSE - ETA: 2s - loss: 1.476 - ETA: 1s - loss: 1.4763 - MS - ETA: 0s - loss: 1.4743 -
# Epoch 15/20
# 393969/393969 [==============================] - 5s 12us/sample - loss: 1.4709 - MSE: 3.8884 - val_loss: 1.9001 - val_MSE: 6.7264
# Epoch 16/20
# 393969/393969 [==============================] - 4s 11us/sample - loss: 1.4686 - MSE: 3.8741 - val_loss: 1.9511 - val_MSE: 7.0802
# Epoch 17/20
# 393969/393969 [==============================] - 7s 17us/sample - loss: 1.4660 - MSE: 3.8611 - val_loss: 1.9795 - val_MSE: 7.3273
# Epoch 18/20
# 393969/393969 [==============================] - 5s 14us/sample - loss: 1.4648 - MSE: 3.8550 - val_loss: 2.0794 - val_MSE: 8.0759 loss: 1.4657 - MSE:
# Epoch 19/20
# 393969/393969 [==============================] - 5s 13us/sample - loss: 1.4640 - MSE: 3.8552 - val_loss: 1.9270 - val_MSE: 6.9673
# Epoch 20/20
# 393969/393969 [==============================] - 5s 14us/sample - loss: 1.4634 - MSE: 3.8504 - val_loss: 1.8827 - val_MSE: 6.5506

# %%
RMSE = sqrt(h.history['val_MSE'][len(h.history['val_MSE'])-1])
print("Score (R2):", r2_score(y_test, model.predict(x_test[input_features_no_cat_no_street])))
print('RMSE:', RMSE)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Score (R2): 0.7451361117210543
# RMSE: 2.5594135397965863

# %%
plot_predicted_data(model.predict(x_val1[input_features_no_cat_no_street]), x_val1, y_val1)

# %%
plt.scatter(y_test, model.predict(x_test[input_features_no_cat_no_street]), color='orange')
plt.plot(range(0, int(y_test.max())+1), range(0, int(y_test.max())+1), color='black')
plt.grid()
plt.xlabel('prueba')
plt.ylabel('predichos')
plt.show()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %% [markdown]
# ### Con embedding

# %%
i = Input(shape=((len(input_features_cat)-3)), name='input')

#id_cuadra
i_street = Input(shape=(1), name='input_street')
emb_street = Embedding(input_dim=max(data_to_split['id_cuadra'].drop_duplicates())+1, output_dim=10)(i_street)
flat_street = Flatten()(emb_street)

#Mes
i_month = Input(shape=(1), name='input_month')
emb_month = Embedding(input_dim=12+1, output_dim=10)(i_month)
flat_month = Flatten()(emb_month)

#dia de la semana
i_weekday = Input(shape=(1), name='input_id_cuadra')
emb_weekday = Embedding(input_dim=5, output_dim=10)(i_weekday)
flat_weekday = Flatten()(emb_weekday)


concat = Concatenate(axis=-1)
input_merge = concat([i, flat_street])
input_merge = concat([input_merge, flat_month])
input_merge = concat([input_merge, flat_weekday])

o = Dense(1, activation='linear')(input_merge)

model = Model(inputs=[i, i_street, i_month, i_weekday], outputs=o)
model.summary()
model.compile(loss='MAE', optimizer='adam', metrics=['MSE'])
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_street (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 10)        1910        input_street[0][0]
# __________________________________________________________________________________________________
# input_month (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input (InputLayer)              [(None, 3)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 10)           0           embedding[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 10)        130         input_month[0][0]
# __________________________________________________________________________________________________
# input_id_cuadra (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       multiple             0           input[0][0]
#                                                                  flatten[0][0]
#                                                                  concatenate[0][0]
#                                                                  flatten_1[0][0]
#                                                                  concatenate[1][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           embedding_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 10)        50          input_id_cuadra[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 10)           0           embedding_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            34          concatenate[2][0]
# ==================================================================================================
# Total params: 2,124
# Trainable params: 2,124
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train1 = x_train[[tiempo, 'ocupacion', 'ocupacion anterior']]
x_train2 = x_train['id_cuadra']
x_train3 = x_train['mes']
x_train4 = x_train['dia de la semana']
x_test1 = x_test[[tiempo, 'ocupacion', 'ocupacion anterior']]
x_test2 = x_test['id_cuadra']
x_test3 = x_test['mes']
x_test4 = x_test['dia de la semana']


h = model.fit([x_train1, x_train2, x_train3, x_train4], y_train, epochs=5, batch_size=64, validation_data=([x_test1, x_test2, x_test3, x_test4], y_test))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>", "<class 'pandas.core.series.Series'>"}), <class 'NoneType'>
# Train on 393969 samples, validate on 43775 samples
# Epoch 1/5
# 393969/393969 [==============================] - 8s 21us/sample - loss: 1.7704 - MSE: 6.1245 - val_loss: 1.5376 - val_MSE: 4.1530
# Epoch 2/5
# 393969/393969 [==============================] - 8s 20us/sample - loss: 1.5383 - MSE: 4.1284 - val_loss: 1.5357 - val_MSE: 4.1250
# Epoch 3/5
# 393969/393969 [==============================] - 7s 19us/sample - loss: 1.5381 - MSE: 4.1266 - val_loss: 1.5361 - val_MSE: 4.1445 4s - - ETA: 3s - loss: 1.5419
# Epoch 4/5
# 393969/393969 [==============================] - 7s 19us/sample - loss: 1.5382 - MSE: 4.1272 - val_loss: 1.5366 - val_MSE: 4.1450- loss: 1.5372
# Epoch 5/5
# 393969/393969 [==============================] - 7s 19us/sample - loss: 1.5378 - MSE: 4.1262 - val_loss: 1.5349 - val_MSE: 4.1259: 1.5357  - ETA: 1s - loss: 1.5371 - MSE:  - ETA: 0s - loss: 1.53

# %%
RMSE = sqrt(h.history['val_MSE'][len(h.history['val_MSE'])-1])
print("Score (R2):", r2_score(y_test, model.predict([x_test1, x_test2, x_test3, x_test4])))
print('RMSE:', RMSE)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>", "<class 'pandas.core.series.Series'>"}), <class 'NoneType'>
# Score (R2): 0.8394741410943155
# RMSE: 2.0312286375829793

# %%
model.layers[1].get_weights()[0] #['id_cuadra', 'mes', 'dia de la semana', tiempo, 'ocupacion', 'ocupacion anterior']
# Out:
# array([[-0.2751622 ,  0.16171014,  0.30078018, ...,  0.17364857,
#         -0.2614901 ,  0.29345635],
#        [-0.11924374,  0.09865618,  0.08169451, ...,  0.0769617 ,
#         -0.11271042,  0.08727697],
#        [-0.07239842,  0.05188746,  0.1192195 , ...,  0.04077515,
#         -0.08493859,  0.12489275],
#        ...,
#        [ 0.00462979, -0.04261866,  0.03431198, ...,  0.01738149,
#          0.03826975,  0.01349875],
#        [ 0.00048964, -0.03029873, -0.03063089, ...,  0.04072819,
#         -0.02828783,  0.02673275],
#        [ 0.29510272, -0.3157003 , -0.2944486 , ..., -0.27328408,
#          0.2715954 , -0.27084228]], dtype=float32)

# %%
plot_predicted_data(model.predict([x_val1[[tiempo, 'ocupacion', 'ocupacion anterior']], x_val1['id_cuadra'], x_val1['mes'], x_val1['dia de la semana']]), x_val1, y_val1)

# %%
plt.scatter(y_test, model.predict([x_test[[tiempo, 'ocupacion', 'ocupacion anterior']], x_test['id_cuadra'], x_test['mes'], x_test['dia de la semana']]), color='orange')
plt.plot(range(0, int(y_test.max())+1), range(0, int(y_test.max())+1), color='black')
plt.grid()
plt.xlabel('prueba')
plt.ylabel('predichos')
plt.show()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>", "<class 'pandas.core.series.Series'>"}), <class 'NoneType'>

# %% [markdown]
# ### Lo mismo pero con mas capas

# %%
i = Input(shape=((len(input_features_cat)-3)), name='input')

#id_cuadra
i_street = Input(shape=(1), name='input_street')
emb_street = Embedding(input_dim=max(data_to_split['id_cuadra'].drop_duplicates())+1, output_dim=10)(i_street)
flat_street = Flatten()(emb_street)

#Mes
i_month = Input(shape=(1), name='input_month')
emb_month = Embedding(input_dim=12+1, output_dim=10)(i_month)
flat_month = Flatten()(emb_month)

#dia de la semana
i_weekday = Input(shape=(1), name='input_id_cuadra')
emb_weekday = Embedding(input_dim=5, output_dim=10)(i_weekday)
flat_weekday = Flatten()(emb_weekday)


concat = Concatenate(axis=-1)
input_merge = concat([i, flat_street])
input_merge = concat([input_merge, flat_month])
input_merge = concat([input_merge, flat_weekday])

d = Dense(64, activation='relu')(input_merge)
d = Dense(64, activation='relu')(d)
d = Dropout(0.3)(d)
d = Dense(64, activation='relu')(d)
o = Dense(1, activation='linear')(d)

model = Model(inputs=[i, i_street, i_month, i_weekday], outputs=o)
model.summary()
model.compile(loss='MAE', optimizer='adam', metrics=['MSE'])
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_street (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 10)        1910        input_street[0][0]
# __________________________________________________________________________________________________
# input_month (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input (InputLayer)              [(None, 3)]          0
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 10)           0           embedding_3[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 1, 10)        130         input_month[0][0]
# __________________________________________________________________________________________________
# input_id_cuadra (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     multiple             0           input[0][0]
#                                                                  flatten_3[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  flatten_4[0][0]
#                                                                  concatenate_1[1][0]
#                                                                  flatten_5[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 10)           0           embedding_4[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 1, 10)        50          input_id_cuadra[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 10)           0           embedding_5[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           2176        concatenate_1[2][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           4160        dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           4160        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            65          dense_7[0][0]
# ==================================================================================================
# Total params: 12,651
# Trainable params: 12,651
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train1 = x_train[[tiempo, 'ocupacion', 'ocupacion anterior']]
x_train2 = x_train['id_cuadra']
x_train3 = x_train['mes']
x_train4 = x_train['dia de la semana']
x_test1 = x_test[[tiempo, 'ocupacion', 'ocupacion anterior']]
x_test2 = x_test['id_cuadra']
x_test3 = x_test['mes']
x_test4 = x_test['dia de la semana']


h = model.fit([x_train1, x_train2, x_train3, x_train4], y_train, epochs=20, batch_size=128, validation_data=([x_test1, x_test2, x_test3, x_test4], y_test))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>", "<class 'pandas.core.series.Series'>"}), <class 'NoneType'>
# Train on 393969 samples, validate on 43775 samples
# Epoch 1/20
# 393969/393969 [==============================] - 6s 16us/sample - loss: 1.5901 - MSE: 4.5627 - val_loss: 2.1155 - val_MSE: 8.1633
# Epoch 2/20
# 393969/393969 [==============================] - 5s 14us/sample - loss: 1.5035 - MSE: 4.0196 - val_loss: 2.1920 - val_MSE: 8.8726
# Epoch 3/20
# 393969/393969 [==============================] - 6s 15us/sample - loss: 1.4608 - MSE: 3.8113 - val_loss: 2.0609 - val_MSE: 7.8451
# Epoch 4/20
# 393969/393969 [==============================] - 8s 19us/sample - loss: 1.4275 - MSE: 3.6478 - val_loss: 2.0908 - val_MSE: 8.0556
# Epoch 5/20
# 393969/393969 [==============================] - 6s 16us/sample - loss: 1.4135 - MSE: 3.5751 - val_loss: 1.9951 - val_MSE: 7.4612 - loss: 1.4185 - MSE: 3.599 - ETA: 3s - loss: 1.4186 - MSE: 3. - ETA: 2s - loss: 1.4184 - - ETA: 2s - loss: 1.4155 - ETA: 1s -
# Epoch 6/20
# 393969/393969 [==============================] - 7s 18us/sample - loss: 1.4016 - MSE: 3.5146 - val_loss: 2.1559 - val_MSE: 8.6494
# Epoch 7/20
# 393969/393969 [==============================] - 7s 18us/sample - loss: 1.3969 - MSE: 3.4920 - val_loss: 1.9420 - val_MSE: 7.1275
# Epoch 8/20
# 393969/393969 [==============================] - 6s 16us/sample - loss: 1.3912 - MSE: 3.4630 - val_loss: 1.9722 - val_MSE: 7.3338
# Epoch 9/20
# 393969/393969 [==============================] - 7s 17us/sample - loss: 1.3879 - MSE: 3.4464 - val_loss: 1.8965 - val_MSE: 6.7128
# Epoch 10/20
# 393969/393969 [==============================] - 7s 17us/sample - loss: 1.3845 - MSE: 3.4301 - val_loss: 1.9260 - val_MSE: 6.9019s - loss: 1.3851 - MSE: 3.4
# Epoch 11/20
# 393969/393969 [==============================] - 7s 17us/sample - loss: 1.3814 - MSE: 3.4117 - val_loss: 1.9571 - val_MSE: 7.0974
# Epoch 12/20
# 393969/393969 [==============================] - 8s 22us/sample - loss: 1.3784 - MSE: 3.3962 - val_loss: 2.0535 - val_MSE: 7.8181
# Epoch 13/20
# 393969/393969 [==============================] - 9s 22us/sample - loss: 1.3757 - MSE: 3.3864 - val_loss: 1.9369 - val_MSE: 7.0139
# Epoch 14/20
# 393969/393969 [==============================] - 7s 18us/sample - loss: 1.3720 - MSE: 3.3671 - val_loss: 1.9176 - val_MSE: 6.7891
# Epoch 15/20
# 393969/393969 [==============================] - 6s 16us/sample - loss: 1.3715 - MSE: 3.3630 - val_loss: 1.9215 - val_MSE: 6.8354- MSE: 3 - ETA: 1s  - ETA: 0s - loss: 1.3718 - MSE: 3.36
# Epoch 16/20
# 393969/393969 [==============================] - 7s 17us/sample - loss: 1.3693 - MSE: 3.3508 - val_loss: 1.9917 - val_MSE: 7.4190
# Epoch 17/20
# 393969/393969 [==============================] - 6s 15us/sample - loss: 1.3668 - MSE: 3.3379 - val_loss: 1.9193 - val_MSE: 6.8659loss: 1.3590 - MSE: 3. - ETA: 3s - loss: 1.3603 - MSE: 3.307 - ETA: 3s - loss: 1.3615 - MSE: 3.3 - ETA: 3s - loss: 1.3628 - MSE: 3.31 - ETA: 3s - loss: 1
# Epoch 18/20
# 393969/393969 [==============================] - 6s 16us/sample - loss: 1.3652 - MSE: 3.3314 - val_loss: 2.0199 - val_MSE: 7.5761
# Epoch 19/20
# 393969/393969 [==============================] - 6s 15us/sample - loss: 1.3639 - MSE: 3.3240 - val_loss: 2.0305 - val_MSE: 7.73493s - loss: 1.366
# Epoch 20/20
# 393969/393969 [==============================] - 6s 16us/sample - loss: 1.3626 - MSE: 3.3155 - val_loss: 1.8599 - val_MSE: 6.4200

# %%
RMSE = sqrt(h.history['val_MSE'][len(h.history['val_MSE'])-1])
print("Score (R2):", r2_score(y_test, model.predict([x_test1, x_test2, x_test3, x_test4])))
print('RMSE:', RMSE)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>", "<class 'pandas.core.series.Series'>"}), <class 'NoneType'>
# Score (R2): 0.7502183734424166
# RMSE: 2.533766637520726

# %%
plot_predicted_data(model.predict([x_val1[[tiempo, 'ocupacion', 'ocupacion anterior']], x_val1['id_cuadra'], x_val1['mes'], x_val1['dia de la semana']]), x_val1, y_val1)

# %%
plt.scatter(y_test, model.predict([x_test[[tiempo, 'ocupacion', 'ocupacion anterior']], x_test['id_cuadra'], x_test['mes'], x_test['dia de la semana']]), color='orange')
plt.plot(range(0, int(y_test.max())+1), range(0, int(y_test.max())+1), color='black')
plt.grid()
plt.xlabel('prueba')
plt.ylabel('predichos')
plt.show()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>", "<class 'pandas.core.series.Series'>"}), <class 'NoneType'>

# %%
print(model.predict([x_val1[[tiempo, 'ocupacion', 'ocupacion anterior']], x_val1['id_cuadra'], x_val1['mes'], x_val1['dia de la semana']]))
print(y_val1)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>", "<class 'pandas.core.series.Series'>"}), <class 'NoneType'>
# [[ 8.832452 ]
#  [10.36046  ]
#  [11.195706 ]
#  [11.539973 ]
#  [11.5071945]
#  [ 6.5393224]
#  [ 4.9961257]
#  [ 5.8386106]
#  [ 5.9057775]
#  [ 4.6320634]
#  [ 4.0988503]
#  [ 6.060835 ]
#  [ 5.5606775]
#  [ 5.1890063]
#  [ 5.843777 ]
#  [ 4.3439755]
#  [ 4.779541 ]
#  [ 2.940684 ]]
# 69693    11
# 69694    14
# 69695    16
# 69696    17
# 69697    10
# 69698     8
# 69699     9
# 69700     9
# 69701     7
# 69702     6
# 69703     8
# 69704     7
# 69705     6
# 69706     7
# 69707     5
# 69708     7
# 69709     6
# 69710     6
# Name: targets, dtype: object

# %% [markdown]
# # LSTM

# %% [markdown]
# ### Se eligen valores de input

# %%
d = data_no_outliers.copy()

# %%
#Esto es si lo quiero con outliers
d = data.copy()

# %%
d
# Out:
#         dia de la semana       fecha  id_cuadra  media hora  mes  ocupacion  \
# 0                      2  2019-01-02          0       36000    1          2
# 1                      2  2019-01-02          0       37800    1          1
# 2                      2  2019-01-02          0       39600    1          5
# 3                      2  2019-01-02          0       41400    1          4
# 4                      2  2019-01-02          0       43200    1          2
# ...                  ...         ...        ...         ...  ...        ...
# 476452                 1  2019-09-17        190       39600    9          1
# 476453                 1  2019-09-17        190       41400    9          1
# 476454                 1  2019-11-12        190       36000   11          0
# 476455                 1  2019-11-19        190       34200   11          1
# 476456                 1  2019-11-19        190       41400   11          1
#
#         ocupacion anterior  targets
# 0                        3        1
# 1                        2        5
# 2                        1        4
# 3                        5        2
# 4                        4        3
# ...                    ...      ...
# 476452                   1        1
# 476453                   1        1
# 476454                   0        1
# 476455                   1        1
# 476456                   1        1
#
# [443191 rows x 8 columns]

# %%
input_features = ['id_cuadra', 'mes', 'dia de la semana', 'ocupacion']

train_size = 3

# %% [markdown]
# ### Se eligen datos de validacion

# %%
cuadra1 = 12
fecha1 = 1

fecha1 = d['fecha'].drop_duplicates().iloc[fecha1]

filt = (d['id_cuadra'] == cuadra1) & (d['fecha'] == fecha1) 
x_val1 = d.loc[filt, ['ocupacion','media hora']]
y_val1 = d.loc[filt, 'targets']

d = d.loc[~filt]


inp_val =[]
inp_time =[]
target_val =[]
for i in range(len(x_val1) - train_size):
    inp_val.append(x_val1['ocupacion'].iloc[i:i+train_size])
    
    inp_time.append(x_val1['media hora'].iloc[i+train_size])

    target_val.append(y_val1.iloc[i+train_size])

# %% [markdown]
# ### Se prepara todo para la LSTM

# %%
emb_data = []
time = []
inp = []
target = []
for s in d['id_cuadra'].drop_duplicates().sort_values():
    clear_output()
    print('calle:', s)
    
    d_s = d.loc[d['id_cuadra'] == s].copy()
    
    for f in d_s['fecha'].drop_duplicates():
        d_f = d_s.loc[d['fecha'] == f]
        
        for i in range(len(d_f) - train_size):
            inp.append(d_f['ocupacion'].iloc[i:i+train_size])
            emb_data.append(d_f[['id_cuadra', 'mes', 'dia de la semana']].iloc[i+train_size-1])
            time.append(d_f['media hora'].iloc[i+train_size-1])
            
            target.append(d_f['targets'].iloc[i+train_size])
# Out:
# calle: 190

# %% [markdown]
# ### Se divide en test y train

# %%
emb_data_df = pd.DataFrame(emb_data)
inp_df = np.array(inp).reshape(-1,train_size,1)
time_df = np.array(time) / (1800*2)
target_df = np.array(target)

# %%
from random import shuffle

to_shuffle = list(zip(inp_df, emb_data_df.to_numpy(), time_df, target_df))
shuffle(to_shuffle)
inp_df, emb_data_df, time_df, target_df = zip(*to_shuffle)

# %%
train_test = int(len(d) * 0.1)

train_inp = inp_df[train_test:]
train_emb_data = emb_data_df[train_test:]
train_time = time_df[train_test:]
train_target = target_df[train_test:]

test_inp = inp_df[:train_test]
test_emb_data = emb_data_df[:train_test]
test_time = time_df[:train_test]
test_target = target_df[:train_test]

# %% [markdown]
# ### LSTM

# %%
i_time = Input(shape=(1), name='input_time')

#id_cuadra
i_street = Input(shape=(1), name='input_street')
emb_street = Embedding(input_dim=max(data_to_split['id_cuadra'].drop_duplicates())+1, output_dim=10)(i_street)
flat_street = Flatten()(emb_street)

#Mes
i_month = Input(shape=(1), name='input_month')
emb_month = Embedding(input_dim=12+1, output_dim=10)(i_month)
flat_month = Flatten()(emb_month)

#dia de la semana
i_weekday = Input(shape=(1), name='input_id_cuadra')
emb_weekday = Embedding(input_dim=5, output_dim=10)(i_weekday)
flat_weekday = Flatten()(emb_weekday)

i_ocup = Input(shape=(train_size,1), name='input_ocup')
lstm = LSTM(10, return_sequences=False, name='lstm')(i_ocup)

concat = Concatenate(axis=-1)
input_merge = concat([i_time, flat_street])
input_merge = concat([input_merge, flat_month])
input_merge = concat([input_merge, flat_weekday])
input_merge = concat([input_merge, lstm])

o = Dense(1, activation='linear')(input_merge)

model = Model(inputs=[i_time, i_street, i_month, i_weekday, i_ocup], outputs=o)
model.summary()
model.compile(loss='MSE', optimizer='adam', metrics=['MAE'])
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_street (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 1, 10)        1910        input_street[0][0]
# __________________________________________________________________________________________________
# input_month (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_time (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 10)           0           embedding_9[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 1, 10)        130         input_month[0][0]
# __________________________________________________________________________________________________
# input_id_cuadra (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     multiple             0           input_time[0][0]
#                                                                  flatten_9[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  flatten_10[0][0]
#                                                                  concatenate_3[1][0]
#                                                                  flatten_11[0][0]
#                                                                  concatenate_3[2][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 10)           0           embedding_10[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, 1, 10)        50          input_id_cuadra[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 10)           0           embedding_11[0][0]
# __________________________________________________________________________________________________
# input_ocup (InputLayer)         [(None, 3, 1)]       0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10)           480         input_ocup[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            42          concatenate_3[3][0]
# ==================================================================================================
# Total params: 2,612
# Trainable params: 2,612
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
train_emb_data = pd.DataFrame(train_emb_data) 
test_emb_data = pd.DataFrame(test_emb_data) #id, mes, weekday
train_time = np.array(train_time) 
test_time = np.array(test_time)

# %%
x_train = [train_time, train_emb_data[0], train_emb_data[1], train_emb_data[2], train_inp]
x_test = [test_time, test_emb_data[0], test_emb_data[1], test_emb_data[2], test_inp]

# %%
h = model.fit(x_train, np.array(train_target), epochs=10, batch_size=64, validation_data=[x_test,np.array(test_target)])
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'numpy.ndarray'>", "<class 'pandas.core.series.Series'>", '(<class \'tuple\'> containing values of types {"<class \'numpy.ndarray\'>"})'}), <class 'NoneType'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-0d09b3769692> in <module>
# ----> 1 h = model.fit(x_train, np.array(train_target), epochs=10, batch_size=64, validation_data=[x_test,np.array(test_target)])
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     640         steps=steps_per_epoch,
#     641         validation_split=validation_split,
# --> 642         shuffle=shuffle)
#     643
#     644     if validation_data:
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2470           feed_input_shapes,
#    2471           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2472           exception_prefix='input')
#    2473
#    2474     # Get typespecs for the input data and sanitize it if necessary.
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     517   if shapes is not None:
#     518     data = [
# --> 519         standardize_single_array(x, shape) for (x, shape) in zip(data, shapes)
#     520     ]
#     521   else:
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in <listcomp>(.0)
#     517   if shapes is not None:
#     518     data = [
# --> 519         standardize_single_array(x, shape) for (x, shape) in zip(data, shapes)
#     520     ]
#     521   else:
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in standardize_single_array(x, expected_shape)
#     442         'Expected an array data type but received an integer: {}'.format(x))
#     443
# --> 444   if (x.shape is not None and len(x.shape) == 1 and
#     445       (expected_shape is None or len(expected_shape) != 1)):
#     446     if tensor_util.is_tensor(x):
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
RMSE = sqrt(h.history['val_loss'][len(h.history['val_loss'])-1])
print("Score (R2):", r2_score(test_target, model.predict(x_test)))
print('RMSE:', RMSE)

# %%
#inp_val = tf.convert_to_tensor(np.array(inp_val).reshape(-1, train_size, 1), np.float64)

# %%
plot_predicted_data(model.predict(x_test), x_val1[train_size:], target_val)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.series.Series'>", '(<class \'tuple\'> containing values of types {"<class \'numpy.ndarray\'>"})', '(<class \'tuple\'> containing values of types {"<class \'numpy.int64\'>"})'}), <class 'NoneType'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-dadf9e1160d8> in <module>
# ----> 1 plot_predicted_data(model.predict(x_test), x_val1[train_size:], target_val)
#
# <ipython-input-14-f33d7923b13c> in plot_predicted_data(predictions, x_val, y_val)
#      12     plt.scatter(targets_time, y_val, color='blue')
#      13
# ---> 14     plt.scatter(targets_time, predictions, color='orange')
#      15     plt.plot(targets_time, predictions, color='orange')
#      16     plt.legend(['Y','Yhat'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4442         y = np.ma.ravel(y)
#    4443         if x.size != y.size:
# -> 4444             raise ValueError("x and y must be the same size")
#    4445
#    4446         if s is None:
#
# ValueError: x and y must be the same size

# %%
plt.scatter(test_target, model.predict(x_test), color='orange')
plt.plot(range(0, int(y_test.max())+1), range(0, int(y_test.max())+1), color='black')
plt.grid()
plt.xlabel('prueba')
plt.ylabel('predichos')
plt.show()

# %%
print('y_pred:', np.array([round(y) for x in model.predict(x_train) for y in x]))
print('y:     ', target_val)

# %%
x_test

# %%
test_time[0]
# Out:
# 14.0
