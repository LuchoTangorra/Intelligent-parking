# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from IPython.display import display, HTML, clear_output
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Embedding, Concatenate, Flatten, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau

from random import shuffle
import datetime

# %%
full_sumo_data_path = r'C:\Users\ing_l\Tesis grado\Data\SUMO\full_SUMO_data_ocupation.csv'

# %%
data = pd.read_csv(full_sumo_data_path)
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
#Delete oficina SUMO and Tribunal de Faltas
data = data.loc[data.parquimetro != 37]
data = data.loc[data.parquimetro != 190]

# %%
data['tiempo_emision'] = data['tiempo_emision'].apply(lambda x: pd.to_datetime(x, dayfirst=True).time())

# %%
d = data.copy()

# %%
d
# Out:
#          parquimetro fecha_emision tiempo_emision  operacion  \
# 0                 16    2019-01-01       10:55:00          0
# 1                 60    2019-01-01       16:25:00          1
# 2                 60    2019-01-01       16:25:00          0
# 3                 60    2019-01-01       16:25:00          1
# 4                 60    2019-01-01       17:11:00          0
# ...              ...           ...            ...        ...
# 2957537           61    2019-12-31       13:20:00          0
# 2957538           61    2019-12-31       13:28:00          0
# 2957539           61    2019-12-31       13:28:00          1
# 2957540           61    2019-12-31       13:28:00          0
# 2957541           61    2019-12-31       13:35:00          0
#
#         tiempo_estacionado      direccion    latitud   longitud  ocupacion
# 0                    10:00   Belgrano 660 -37.328838 -59.134455          0
# 1                     0:00  Chacabuco 357 -37.328143 -59.136740          1
# 2                     0:00  Chacabuco 357 -37.328143 -59.136740          0
# 3                     0:00  Chacabuco 357 -37.328143 -59.136740          1
# 4                     0:46  Chacabuco 357 -37.328143 -59.136740          0
# ...                    ...            ...        ...        ...        ...
# 2957537               0:38   Yrigoyen 847 -37.323967 -59.139628          1
# 2957538               2:22   Yrigoyen 847 -37.323967 -59.139628          0
# 2957539               2:22   Yrigoyen 847 -37.323967 -59.139628          1
# 2957540               2:22   Yrigoyen 847 -37.323967 -59.139628          0
# 2957541               1:39   Yrigoyen 847 -37.323967 -59.139628          0
#
# [2951877 rows x 9 columns]

# %%
def normalize_time(time):
    '''
    normalize time (datetime.time to values bertween 0 and 1
    '''
    max_time = 24 * 60 * 60 + 60 * 60 + 60
    return (time.hour * 60 * 60 + time.minute * 60 + time.second) / max_time

# %%
#Normalize time to values between 0 and 1
d['tiempo_emision'] = d['tiempo_emision'].apply(normalize_time)

# %%
d[0:50]
# Out:
#     parquimetro fecha_emision  tiempo_emision  operacion tiempo_estacionado  \
# 0            16    2019-01-01        0.436376          0              10:00
# 1            60    2019-01-01        0.656229          1               0:00
# 2            60    2019-01-01        0.656229          0               0:00
# 3            60    2019-01-01        0.656229          1               0:00
# 4            60    2019-01-01        0.686875          0               0:46
# 5            76    2019-01-01        0.942705          1               0:00
# 6            76    2019-01-01        0.942705          0               0:00
# 7             1    2019-01-01        0.607595          1               0:00
# 8             1    2019-01-01        0.609594          0               0:03
# 9            65    2019-01-01        0.608261          1               0:00
# 10           65    2019-01-01        0.654231          0               1:09
# 11            9    2019-01-01        0.820786          1               0:00
# 12           18    2019-01-01        0.686209          1               0:00
# 13           18    2019-01-01        0.686209          0               0:00
# 14           66    2019-01-02        0.345103          1               0:00
# 15           66    2019-01-02        0.392405          1               0:00
# 16           66    2019-01-02        0.406396          0               1:32
# 17           66    2019-01-02        0.416389          0               0:24
# 18           66    2019-01-02        0.420386          0               0:42
# 19           66    2019-01-02        0.453031          1               0:00
# 20           66    2019-01-02        0.456362          1               0:00
# 21           66    2019-01-02        0.458361          1               0:00
# 22           66    2019-01-02        0.466356          0               0:12
# 23           66    2019-01-02        0.475017          1               0:00
# 24           66    2019-01-02        0.475683          1               0:00
# 25           66    2019-01-02        0.492338          0               0:25
# 26           66    2019-01-02        0.494337          1               0:00
# 27           66    2019-01-02        0.494337          0               0:00
# 28           66    2019-01-02        0.494337          0               0:29
# 29           66    2019-01-02        0.583611          1               0:00
# 30           66    2019-01-02        0.614257          0               0:46
# 31           66    2019-01-02        0.687542          1               0:00
# 32           66    2019-01-02        0.700200          0               0:19
# 33           66    2019-01-02        0.723518          1               0:00
# 34           66    2019-01-02        0.728181          0               0:07
# 35           66    2019-01-02        0.738175          1               0:00
# 36           66    2019-01-02        0.754830          1               0:00
# 37           66    2019-01-02        0.763491          0               0:38
# 38           66    2019-01-02        0.766822          1               0:00
# 39           66    2019-01-02        0.773484          0               0:10
# 40           66    2019-01-02        0.795470          0               1:01
# 41           54    2019-01-02        0.379747          1               0:00
# 42           54    2019-01-02        0.389074          1               0:00
# 43           54    2019-01-02        0.398401          0               0:28
# 44           54    2019-01-02        0.399067          0               0:15
# 45           54    2019-01-02        0.461026          1               0:00
# 46           54    2019-01-02        0.477682          1               0:00
# 47           54    2019-01-02        0.482345          0               0:07
# 48           54    2019-01-02        0.506329          0               1:08
# 49           54    2019-01-02        0.515656          1               0:00
#
#             direccion    latitud   longitud  ocupacion
# 0        Belgrano 660 -37.328838 -59.134455          0
# 1       Chacabuco 357 -37.328143 -59.136740          1
# 2       Chacabuco 357 -37.328143 -59.136740          0
# 3       Chacabuco 357 -37.328143 -59.136740          1
# 4       Chacabuco 357 -37.328143 -59.136740          0
# 5     General Paz 547 -37.325210 -59.128828          1
# 6     General Paz 547 -37.325210 -59.128828          0
# 7   General Pinto 545 -37.327782 -59.136657          1
# 8   General Pinto 545 -37.327782 -59.136657          0
# 9       Rodriguez 348 -37.329387 -59.134833          1
# 10      Rodriguez 348 -37.329387 -59.134833          0
# 11      Rodriguez 654 -37.325728 -59.137127          1
# 12      Sarmiento 543 -37.323307 -59.139643          1
# 13      Sarmiento 543 -37.323307 -59.139643          0
# 14    14 de Julio 347 -37.330855 -59.138545          1
# 15    14 de Julio 347 -37.330855 -59.138545          2
# 16    14 de Julio 347 -37.330855 -59.138545          1
# 17    14 de Julio 347 -37.330855 -59.138545          0
# 18    14 de Julio 347 -37.330855 -59.138545          0
# 19    14 de Julio 347 -37.330855 -59.138545          1
# 20    14 de Julio 347 -37.330855 -59.138545          2
# 21    14 de Julio 347 -37.330855 -59.138545          3
# 22    14 de Julio 347 -37.330855 -59.138545          2
# 23    14 de Julio 347 -37.330855 -59.138545          3
# 24    14 de Julio 347 -37.330855 -59.138545          4
# 25    14 de Julio 347 -37.330855 -59.138545          3
# 26    14 de Julio 347 -37.330855 -59.138545          4
# 27    14 de Julio 347 -37.330855 -59.138545          3
# 28    14 de Julio 347 -37.330855 -59.138545          2
# 29    14 de Julio 347 -37.330855 -59.138545          3
# 30    14 de Julio 347 -37.330855 -59.138545          2
# 31    14 de Julio 347 -37.330855 -59.138545          3
# 32    14 de Julio 347 -37.330855 -59.138545          2
# 33    14 de Julio 347 -37.330855 -59.138545          3
# 34    14 de Julio 347 -37.330855 -59.138545          2
# 35    14 de Julio 347 -37.330855 -59.138545          3
# 36    14 de Julio 347 -37.330855 -59.138545          4
# 37    14 de Julio 347 -37.330833 -59.138693          3
# 38    14 de Julio 347 -37.330833 -59.138693          4
# 39    14 de Julio 347 -37.330833 -59.138693          3
# 40    14 de Julio 347 -37.330833 -59.138693          2
# 41    14 de Julio 467 -37.329478 -59.139525          1
# 42    14 de Julio 467 -37.329478 -59.139525          2
# 43    14 de Julio 467 -37.329478 -59.139525          1
# 44    14 de Julio 467 -37.329478 -59.139525          0
# 45    14 de Julio 467 -37.329902 -59.139782          1
# 46    14 de Julio 467 -37.329902 -59.139782          2
# 47    14 de Julio 467 -37.329902 -59.139782          1
# 48    14 de Julio 467 -37.329902 -59.139782          0
# 49    14 de Julio 467 -37.329902 -59.139782          1

# %%
max_time = 24 * 60 * 60 + 60 * 60 + 60

eight_am = (8 * 60 * 60) / max_time
ten_pm = (22 * 60 * 60) / max_time

d = d.loc[d.tiempo_emision >= eight_am]
d = d.loc[d.tiempo_emision <= ten_pm]

# %%
d
# Out:
#          parquimetro fecha_emision  tiempo_emision  operacion  \
# 0                 16    2019-01-01        0.436376          0
# 1                 60    2019-01-01        0.656229          1
# 2                 60    2019-01-01        0.656229          0
# 3                 60    2019-01-01        0.656229          1
# 4                 60    2019-01-01        0.686875          0
# ...              ...           ...             ...        ...
# 2957537           61    2019-12-31        0.532978          0
# 2957538           61    2019-12-31        0.538308          0
# 2957539           61    2019-12-31        0.538308          1
# 2957540           61    2019-12-31        0.538308          0
# 2957541           61    2019-12-31        0.542971          0
#
#         tiempo_estacionado      direccion    latitud   longitud  ocupacion
# 0                    10:00   Belgrano 660 -37.328838 -59.134455          0
# 1                     0:00  Chacabuco 357 -37.328143 -59.136740          1
# 2                     0:00  Chacabuco 357 -37.328143 -59.136740          0
# 3                     0:00  Chacabuco 357 -37.328143 -59.136740          1
# 4                     0:46  Chacabuco 357 -37.328143 -59.136740          0
# ...                    ...            ...        ...        ...        ...
# 2957537               0:38   Yrigoyen 847 -37.323967 -59.139628          1
# 2957538               2:22   Yrigoyen 847 -37.323967 -59.139628          0
# 2957539               2:22   Yrigoyen 847 -37.323967 -59.139628          1
# 2957540               2:22   Yrigoyen 847 -37.323967 -59.139628          0
# 2957541               1:39   Yrigoyen 847 -37.323967 -59.139628          0
#
# [2942107 rows x 9 columns]

# %%
def get_mean_time(data):
    '''
    Get the mean of the difference in team on each row.
    '''
    
    
    df = data.copy()

    mean = 0
    cant = 0
    
    max_time = 24 * 60 * 60 + 60 * 60 + 60
    
    for street in df['parquimetro'].drop_duplicates().sort_values():
        clear_output()
        print('Street:', street)
        if (cant != 0):
            print('Mean:', mean/cant)
        d_street = df.loc[df['parquimetro'] == street]
        
        for date in d_street['fecha_emision'].drop_duplicates().sort_values():
            d_date = d_street.loc[d_street['fecha_emision'] == date].reset_index(drop=True)
            
            d_date = d_date.drop_duplicates(subset='tiempo_emision').reset_index(drop=True)
            #display(d_date)
            def add_mean(time):
                nonlocal d_date, mean, cant

                past_data = d_date[d_date['tiempo_emision'] < time]
                
                if len(past_data) > 0:
                    cant += 1
                    past_time_row_ix = past_data.tiempo_emision.idxmax()
                    other_time = d_date.iloc[past_time_row_ix]['tiempo_emision']
                    mean += (time - other_time)
                return time
            
            _ = d_date['tiempo_emision'].apply(add_mean)
                        
            '''for ix in d_date.index:
                row_to_add = d_date.iloc[ix]
                past_time = row_to_add['tiempo_emision'] - t
                
                past_data = d_date[d_date['tiempo_emision'] <= past_time]
                if len(past_data) > 0:
                    past_time_row_ix = past_data.tiempo_emision.idxmax()
                    row_to_add['ocupacion_pasada'] = d_date.iloc[past_time_row_ix]['ocupacion']
                else:
                    row_to_add['ocupacion_pasada'] = row_to_add['ocupacion']
                
                out = out.append(row_to_add)
            '''    
    mean = mean/cant
    return mean

# %%
mean_time = get_mean_time(d)
# Out:
# Street: 96
# Mean: 0.00470024319771747

# %%
def denormalize_time(time):
    '''
    denormalize time (datetime.time to values bertween 0 and 1
    '''
    max_time = 24 * 60 * 60 + 60 * 60 + 60
    return pd.Timestamp(time * max_time, unit='s').time()

denormalize_time(0.00470024319771747)
# Out:
# datetime.time(0, 7, 3, 303902)
